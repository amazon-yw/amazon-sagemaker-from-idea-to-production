# %% [markdown]
# # 4단계: 모델 빌드 CI/CD 파이프라인 추가
#
# <div style="border: 2px solid #ff9900; border-radius: 8px; padding: 15px; background-color: #fff3e0; margin-bottom: 10px;">
# <strong>⚠️ 호환성 안내:</strong> 이 노트북은 <strong>SageMaker Distribution Image 4.0.0</strong> 및 <strong>SageMaker Python SDK 버전 3.7.1</strong>에서 테스트되었습니다.
# </div>
#
# 이 노트북에서는 노트북 03에서 구축한 ML 파이프라인을 위한 CI/CD를 구현하는 SageMaker MLOps 프로젝트를 생성합니다.
#
# ||||
# |---|---|---|
# |1. |노트북에서 실험하기 ||
# |2. |SageMaker AI 처리 작업과 SageMaker SDK로 확장하기 ||
# |3. |ML 파이프라인, 모델 레지스트리로 운영화하기 ||
# |4. |모델 빌드 CI/CD 파이프라인 추가하기 |**<<<< 현재 위치**|
# |5. |모델 배포 파이프라인 추가하기 ||
# |6. |모델 및 데이터 모니터링 추가하기 ||
#
# 이 프로젝트는 다음을 사용합니다:
#
# - **S3 기반 프로젝트 템플릿** — 커스텀 SageMaker 프로젝트 템플릿을 위한 권장 방식
# - **AWS CodePipeline** — 모델 빌드 및 배포 파이프라인 오케스트레이션
# - **AWS CodeBuild** — 코드 푸시마다 SageMaker 파이프라인 빌드 및 실행
# - **GitHub 저장소** — 모델 빌드 및 배포 코드의 소스 제어
# - **EventBridge** — 레지스트리에서 모델이 승인될 때 배포 파이프라인 트리거
#
# 프로젝트 템플릿은 두 개의 파이프라인을 프로비저닝합니다:
# 1. **모델 빌드 파이프라인** — 모델 빌드 저장소에 코드가 푸시될 때 트리거됩니다. 데이터 전처리, 훈련, 평가, 모델 등록을 수행하는 SageMaker 파이프라인을 실행합니다.
# 2. **모델 배포 파이프라인** — SageMaker 모델 레지스트리에서 모델이 승인될 때 트리거됩니다. 스테이징에 모델을 배포하고, 테스트를 실행하고, (수동 승인 후) 프로덕션에 배포합니다.
#
# ![](img/MLOps-with-SageMaker-small.png)

# %%
import sys

assert sys.version_info[:2] == (3, 10), f"Expected Python 3.10, got {sys.version_info.major}.{sys.version_info.minor}. Please make sure you run on Python 3.10"

# %%
import boto3
import json
from time import gmtime, strftime, sleep
from IPython.display import HTML
from sagemaker.core.helper.session_helper import Session, get_execution_role

# %%
# %store -r 

# %store

try:
    initialized
except NameError:
    print("+++++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN 00-start-here notebook   ")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sm = boto3.client("sagemaker")

# %% [markdown]
# ## S3 기반 SageMaker AI 프로젝트 템플릿
#
# S3 버킷에서 직접 커스텀 프로젝트 템플릿을 배포합니다. AWS는 현재 대부분의 사용 사례에 이 방식을 권장합니다.
#
# ### 개요
#
# S3 기반 템플릿은 커스텀 SageMaker AI 프로젝트를 위한 권장 방식으로 다음을 제공합니다:
#
# - Service Catalog 복잡성 없는 **간소화된 템플릿 프로비저닝**
# - S3에서의 **직접 템플릿 관리**
# - 개발 및 테스트를 위한 **빠른 반복 주기**
# - 다양한 사용 사례를 위한 **유연한 템플릿 구조**
# - 대부분의 시나리오에 **비용 효율적인** 솔루션
#
# ![](./img/sm-projects-custom-template-s3.png)

# %% [markdown]
# ## S3 기반 템플릿 설정 지침
# ### SageMaker AI Studio 도메인 설정
#
# 템플릿을 저장할 S3 버킷을 지정하기 위해 `sagemaker:projectS3TemplatesLocation`을 대상 버킷으로 설정하여 SageMaker AI 도메인에 태그를 추가합니다.

# %%
sm = boto3.client('sagemaker')

domain_arn = sm.describe_domain(DomainId=domain_id)['DomainArn']

# Tag a domain
sm.add_tags(
    ResourceArn=domain_arn,
    Tags=[
        {'Key': 'sagemaker:projectS3TemplatesLocation', 'Value': f's3://{bucket_name}/templates/'},
    ]
)

# %% [markdown]
# 버킷에 CORS 정책을 추가합니다. CORS 정책은 SageMaker AI Studio 도메인 UI에서 템플릿을 표시하는 데 필요합니다.

# %%
s3 = boto3.client('s3')

# 1. Put bucket CORS
with open('sm-custom-projects/cors-policy.json') as f:
    cors_config = json.load(f)
s3.put_bucket_cors(Bucket=bucket_name, CORSConfiguration=cors_config)

# %% [markdown]
# 템플릿을 업로드하고 `sagemaker:studio-visibility`를 `true`로 설정하여 태그를 지정합니다.

# %%
# Upload file
s3.upload_file('sm-custom-projects/build-train-deploy-codepipeline.yaml', bucket_name, 'templates/build-train-deploy-codepipeline.yaml')

# Tag the object
s3.put_object_tagging(
    Bucket=bucket_name,
    Key='templates/build-train-deploy-codepipeline.yaml',
    Tagging={'TagSet': [{'Key': 'sagemaker:studio-visibility', 'Value': 'true'}]}
)

# %% [markdown]
# ### 필요한 IAM 역할 및 정책
#
# SageMaker Projects는 보안과 관심사 분리를 유지하기 위해 두 가지 유형의 IAM 역할을 사용합니다:
#
# #### 사용 역할 (Use Roles)
#
# MLOps 파이프라인 내에서 지정된 작업을 수행하기 위해 AWS 서비스가 맡는 서비스별 실행 역할입니다:
#
# - **AmazonSageMakerProjectsCloudformationRole** - SageMaker 리소스를 관리하는 CloudFormation 역할
# - **AmazonSageMakerProjectsCodeBuildRole** - 컨테이너 이미지를 빌드하고 푸시하는 CodeBuild 역할
# - **AmazonSageMakerProjectsCodePipelineRole** - CI/CD 워크플로우를 오케스트레이션하는 CodePipeline 역할
# - **AmazonSageMakerProjectsExecutionRole** - SageMaker 훈련 및 추론 작업 역할
# - **AmazonSageMakerProjectsLambdaRole** - MLOps 워크플로우에서 사용되는 Lambda 함수 역할
# - **AmazonSageMakerProjectsUseRole** - 다양한 SageMaker 프로젝트 서비스를 위한 범용 역할
#
# #### 시작 역할 (Launch Role)
#
# **AmazonSageMakerProjectsLaunchRole**은 프로젝트 생성 중 중개자 역할을 하는 프로비저닝 역할입니다:
#
# - **목적**: 프로젝트 인프라(IAM 역할, S3 버킷, CodePipeline 등)를 생성하는 데 필요한 모든 권한 포함
# - **이점**: ML 엔지니어와 데이터 과학자가 광범위한 권한 없이 프로젝트를 생성할 수 있음
# - **보안**: 개인 SageMaker 실행 역할은 제한적으로 유지됨
#
# 이 워크샵에서는 이러한 권한 세트가 이미 프로비저닝되어 있습니다.

# %%
import boto3

cfn = boto3.client('cloudformation')
iam = boto3.client('iam')

try:
    iam.get_role(RoleName='AmazonSageMakerProjectsLaunchRole')
    print("Role exists, skip CFN creation")
except iam.exceptions.NoSuchEntityException:
    # Deploy CloudFormation stack
    with open('sm-custom-projects/sagemaker-projects-roles-and-policies.yaml') as f:
        template_body = f.read()
    print("Role does not exist, provision the CFN stack")

    cfn.create_stack(
        StackName='sagemaker-projects-roles-policies',
        TemplateBody=template_body,
        Capabilities=['CAPABILITY_NAMED_IAM'],
        Parameters=[{'ParameterKey': 'SageMakerExecutionRoleArn', 'ParameterValue': sm_role}]
    )
    
    # Wait for completion (equivalent to 'deploy' which waits)
    waiter = cfn.get_waiter('stack_create_complete')
    waiter.wait(StackName='sagemaker-projects-roles-policies')

# %% [markdown]
# ## MLOps 프로젝트 생성

# %% [markdown]
# ### 준비
#
# <div class="alert alert-info"><b>사전 요구사항:</b> 아래에 설명된 대로 AWS 계정에서 GitHub 사용자 또는 조직으로의 AWS CodeStar 연결을 설정해야 합니다.<br/><b>이 AWS CodeStar 연결에 키 <code>sagemaker</code>, 값 <code>true</code>인 태그를 추가하세요.</b></div>
#
# 자세한 지침은 SageMaker 개발자 가이드의 [타사 Git 저장소를 사용한 SageMaker AI MLOps 프로젝트 연습](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-projects-walkthrough-3rdgit.html)을 참조하세요.
#
# <div class="alert alert-info">GitHub 계정에 두 개의 새 빈 비공개 저장소를 생성해야 합니다. 하나는 모델 빌드 파이프라인용이고 다른 하나는 모델 배포 파이프라인용입니다. 예를 들어 저장소 이름을 <code>model-build</code>와 <code>model-deploy</code>로 지정할 수 있습니다.</div>

# %% [markdown]
# #### GitHub 연결 설정
#
# 접근하고 [AWS CodeConnection 연결](https://docs.aws.amazon.com/dtconsole/latest/userguide/welcome-connections.html)을 통해 연결할 수 있는 GitHub 개인 계정이 필요합니다.
#
# 다음 지침에 따라 GitHub에 연결하세요:
#
# GitHub 개인 계정에 두 개의 빈 저장소를 생성하는 것부터 시작합니다. 이 두 저장소는 모델 빌드 워크플로우와 모델 배포 워크플로우를 위한 시드 코드로 채워집니다. [GitHub.com](https://github.com/)으로 이동하여 사용자 드롭다운 메뉴에서 내 저장소로 이동합니다.
# model-build 저장소를 생성합니다.
#
# ![](img/github-model-build.png)
#
# model-deploy 저장소에 대해 동일한 과정을 반복합니다.
#
# ![](img/github-model-deploy.png)
#
# 이제 코드 변경 시 워크플로우 트리거를 활성화하기 위해 [연결](https://docs.aws.amazon.com/dtconsole/latest/userguide/welcome-connections.html)(AWS 내 개발자 도구의 일부)을 통해 개인 GitHub 계정을 AWS 계정에 연결해야 합니다. [연결](https://console.aws.amazon.com/codesuite/settings/connections)로 이동하여 새 연결을 생성합니다.
#
# ![](img/crete-connection.png)
#
# GitHub를 공급자로 선택하고 이름(예: `mlops-connection`)을 지정하고 키가 sagemaker이고 값이 true인 새 태그를 추가합니다.
#
# ![](img/github-connection.png)
#
# GitHub 계정에 인증하라는 메시지가 표시됩니다. 모범 사례로, 새 앱을 설치하여 방금 생성한 두 저장소(model-build와 model-deploy)에만 권한을 제한하는 것을 권장합니다.
#
# ![](img/install-github-app.png)
# <img src="img/connection-permissions.png" width="500" height="800" alt="Description">
#
# 연결을 생성하고 ARN을 아래 셀에 복사하여 붙여넣습니다.

# %%
# set this variable to the ARN of your code connection your created
code_connection_arn = "<CODECONNECTION-ARN>"

# %% [markdown]
# 이 노트북에서 프로그래밍 방식으로 프로젝트를 생성할 수 있습니다 - **옵션 1** 또는 Studio UI에서 - **옵션 2**.
#
# 옵션 1은 UX에 대한 의존성이 없으므로 권장됩니다.</br>
# 옵션 2는 [**프로젝트 생성** UI 흐름](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-projects-create.html)을 보여주기 위해 제공됩니다.

# %% [markdown]
# ### 옵션 1: 프로그래밍 방식으로 프로젝트 생성 - 권장
# 이 섹션에서는 `boto3`를 사용하여 SageMaker API를 통해 MLOps 프로젝트를 생성합니다.

# %%
# set unique project name
project_name = f"mlops-{strftime('%m-%d-%H-%M-%S', gmtime())}"

# %% [markdown]
# 프로젝트 템플릿의 파라미터를 설정합니다. `model_build_code_repository_full_name`과 `model_deploy_code_repository_full_name` 변수를 GitHub 저장소의 전체 이름으로 설정합니다. 이는 새 빈 저장소여야 합니다.

# %%
# Branch name for the Model Building and Training Code Repository
model_build_code_repository_branch = 'main'
# Full repository name of the Model Building and Training Code Repository, which would be username/reponame or organizationname/reponame
model_build_code_repository_full_name = "<REPLACE-ME>" # e.g. username/reponame

# Branch name for the Model Deployment Code Repository
model_deploy_code_repository_branch = 'main'
# Full repository name of the Model Deployment Code Repository, which would be username/reponame or organizationname/reponame
model_deploy_code_repository_full_name = "<REPLACE-ME>" # e.g. username/reponame

# %%
# set project parameters
project_parameters = [
    {
        'Key': 'ModelBuildCodeRepositoryBranch',
        'Value': model_build_code_repository_branch,
    },
    {
        'Key': 'ModelBuildCodeRepositoryFullname',
        'Value': model_build_code_repository_full_name,
    },
    {
        'Key': 'ModelDeployCodeRepositoryBranch',
        'Value': model_deploy_code_repository_branch,
    },
    {
        'Key': 'ModelDeployCodeRepositoryFullname',
        'Value': model_deploy_code_repository_full_name,
    },
    {
        'Key': 'CodeConnectionArn',
        'Value': code_connection_arn,
    },
    {
        'Key': 'ModelPackageGroupName',
        'Value': target_model_package_group_name,  # Auto-synced group name from notebook 03
    },
]

print(f"ModelPackageGroupName: {target_model_package_group_name}")
print(f"This will be used for the EventBridge trigger and deploy CodeBuild.")

# %%
sagemaker_project_launch_role_arn = boto3.client('iam').get_role(RoleName='AmazonSageMakerProjectsLaunchRole')['Role']['Arn']
sagemaker_project_launch_role_arn

# create SageMaker project
r = sm.create_project(
    ProjectName=project_name,
    ProjectDescription="Model build and deploy project",
    TemplateProviders=[
        {
            'CfnTemplateProvider': {
                'TemplateName': 'MLOpsTemplate',
                'TemplateURL': f'https://{bucket_name}.s3.{region}.amazonaws.com/templates/build-train-deploy-codepipeline.yaml',
                'RoleARN': sagemaker_project_launch_role_arn,
                'Parameters': project_parameters
            }
        }
    ]
)

print(r)

# %% [markdown]
# <div class="alert alert-info">다음 셀을 실행하여 프로젝트 생성이 완료될 때까지 기다립니다.</div>

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert open medium"/>

# %%
# Project creation takes about 3-5 min
status = sm.describe_project(ProjectName=project_name)['ProjectStatus']
while status not in ['CreateCompleted', 'CreateFailed']:
    print("Waiting for project creation completion")
    sleep(10)
    status = sm.describe_project(ProjectName=project_name)['ProjectStatus']
    
print(f"MLOps project {project_name} creation status: {status}")

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %%
assert sm.describe_project(ProjectName=project_name)['ProjectStatus'] == 'CreateCompleted', 'Project status must be CreateCompleted!'

# %% [markdown]
# ### 옵션 1 종료: 프로그래밍 방식으로 프로젝트 생성
# 이제 SageMaker 환경에 프로젝트 템플릿이 프로비저닝되었습니다. **MLOps 프로젝트 설정** 섹션으로 이동합니다.
#
# ---

# %% [markdown]
# ### 옵션 2: Studio UI에서 프로젝트 생성
# <div class="alert alert-info"><b>프로그래밍 방식으로 프로젝트를 이미 생성한 경우 이 섹션을 건너뛰세요.</b></div>
#
# <div class="alert alert-info">MLOps 프로젝트를 생성하기 전에 <b>준비</b> 단계를 완료해야 합니다.</div>

# %% [markdown]
# ## 커스텀 템플릿 시작
#
# ### AWS 콘솔 (Studio)
# 1. SageMaker Studio 열기
# 2. **배포** > **프로젝트** > **프로젝트 생성**으로 이동
# 3. **조직 템플릿** > **S3 템플릿** 선택
# ![](./img/sm-projects-custom-template-s3.png)
# 5. 템플릿을 선택하고 **다음** 클릭
# 6. 프로젝트 세부 정보 입력 - `역할 ARN` 필드에 **AmazonSageMakerProjectsLaunchRole**의 ARN을 입력합니다.
# ![](./img/LaunchRole.png)
# 7. **생성** 클릭.
#
# 프로젝트가 생성될 때까지 기다립니다.

# %% [markdown]
# ### 옵션 2 종료: Studio UI에서 프로젝트 생성
# 프로젝트가 생성되면 **MLOps 프로젝트 설정** 섹션으로 이동합니다.
#
# ---

# %% [markdown]
# ## MLOps 프로젝트 설정
# 프로비저닝된 MLOps 프로젝트는 두 개의 CodePipeline 파이프라인을 구현합니다. 하나는 모델 빌드용이고 다른 하나는 모델 배포용입니다. 프로젝트는 또한 지정한 두 개의 GitHub 저장소에 시드 코드를 채웁니다. 이 노트북은 모델 빌드 파이프라인을 설명하고 설정합니다. 다음 노트북 `05-deploy`는 두 번째 부분인 모델 배포 파이프라인을 다룹니다.

# %% [markdown]
# ### 모델 빌드 파이프라인
#
# 프로젝트는 생성되는 즉시 기본 모델 빌드 파이프라인을 자동으로 프로비저닝하고 실행합니다. 이 파이프라인은 프로젝트의 샘플 플레이스홀더입니다. 지금은 기본 파이프라인을 무시하세요.
# 프로젝트 템플릿은 AWS 계정에 다음 리소스를 배포합니다:
#
# ![](img/mlops-model-build-train.png)
#
# 주요 구성 요소:
# 1. SageMaker Projects와 AWS Service Catalog 포트폴리오를 통해 프로젝트 템플릿 제공
# 2. `Source` 단계(GitHub 저장소에서 소스 코드 다운로드)와 `Build` 단계(SageMaker 파이프라인 생성 및 실행)가 있는 CodePipeline 파이프라인
# 3. 모델 빌드, 훈련, 등록 워크플로우가 있는 기본 SageMaker 파이프라인
# 4. 제공된 기본 시드 코드 버전이 있는 GitHub의 시드 코드 저장소

# %% [markdown]
# 이 프로젝트에는 사전 정의된 템플릿에서 자동화된 CI/CD 파이프라인을 구현하는 데 필요한 모든 코드와 인프라가 포함되어 있습니다.
# 프로젝트에서 파이프라인을 사용하려면 다음 단계를 완료해야 합니다:
# 1. 프로젝트 GitHub 저장소를 노트북 로컬 스토리지에 클론
# 2. ML 파이프라인 템플릿 샘플 코드를 3단계 노트북에서 구현한 실제 파이프라인 구성 코드로 교체
# 3. 올바른 Python 모듈 이름을 참조하고 프로젝트 파라미터를 설정하도록 `codebuild-buildspec.yml` 파일 수정

# %%
try:
    print(project_name)
    print(project_id)
    print(model_build_code_repository_full_name)
    print(code_connection_arn)
except NameError:
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("Set the code_connection_arn, project_name, and repository full name in the following code cell")
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")

# %%
# project_name = "<SET TO THE NAME OF THE CREATED PROJECT>" # Keep commented out if you used option 1 to create a project
# model_build_code_repository_full_name = "<SET TO THE FULL NAME OF MODEL BUILD REPO>" # Keep commented out if you used option 1 to create a project

r = sm.describe_project(ProjectName=project_name)
project_id = r['ProjectId']
project_arn = r['ProjectArn']
repository_name = model_build_code_repository_full_name.split('/')[1]
git_folder = project_name
project_folder = f'sagemaker-{project_id}-modelbuild'
project_path = f'{git_folder}/{project_folder}'

# %store project_name
# %store project_arn
# %store project_id
    
print(f"Project path: {project_path}")

# %% [markdown]
# ### Studio UI에서 프로젝트 탐색
#
# 다음 코드 셀로 구성된 링크를 클릭합니다. Studio UI에서 프로젝트와 프로젝트 구성 요소를 탐색합니다.

# %%
# Show the project link
display(
    HTML('<b>See <a target="top" href="https://studio-{}.studio.{}.sagemaker.aws/projects/{}/">the project</a> in the Studio UI</b>'.format(
            domain_id, region, project_name))
)

# %% [markdown]
# ### 1. 프로젝트 시드 코드를 JupyterLab 파일 시스템에 클론
# JupyterLab 터미널과 GitHub CLI를 사용하여 GitHub 저장소에서 프로젝트 코드를 클론해야 합니다.
#
# 1. **File** > **New** > **Terminal**을 통해 새 터미널 창을 엽니다
# 2. 다음 셀의 출력을 복사하여 터미널 명령줄에 붙여넣습니다
# 3. `codeconnections` 자격 증명 헬퍼와 함께 `git clone`을 사용하여 모델 빌드 저장소를 클론합니다.

# %%
def copy_output(text):
    return HTML(f'''
        <div style="position: relative;">
            <pre>{text}</pre>
            <button onclick="navigator.clipboard.writeText(`{text}`)"
                    style="position: absolute; top: 5px; right: 5px;">
                Copy
            </button>
        </div>
    ''')
    
cmd = f'''
git config --global credential.UseHttpPath true
git config --global credential.helper 'cache --timeout=720000'
git config --global credential.helper '!aws codecommit credential-helper $@'

mkdir -p $HOME/{project_path}

git clone https://codeconnections.{region}.amazonaws.com/git-http/{code_connection_arn.split(':')[4]}/{region}/{code_connection_arn.split(':')[-1].split('/')[-1]}/{model_build_code_repository_full_name}.git  $HOME/{project_path}
'''

copy_output(cmd)

# %% [markdown]
# ### 2. 파이프라인 구성 코드 교체

# %% [markdown]
# 다음 단계는 시드 코드가 포함된 프로젝트를 커스터마이즈하는 데 필요합니다. 다음 코드 셀이 필요한 모든 단계를 실행하므로 수동으로 할 필요가 없습니다. 다음 텍스트는 참고용입니다.
#
# - 시드 소스 코드는 `<project_name>/sagemaker-<project-id>-modelbuild` 폴더에 있습니다.
# - 원본 파일 `codebuild-buildspec.yml`은 `codebuild-buildspec-original.yml`로 이름이 변경됩니다.
# - 파이프라인 코드가 포함된 MLOps 프로젝트 코드 저장소 폴더는 `abalone` 폴더에서 `fromideatoprod`로 이름이 변경됩니다.
# - 템플릿 파이프라인이 포함된 원본 파일 `pipeline.py`는 `pipeline-original.py`로 이름이 변경됩니다.
# - `pipeline_steps` Python 모듈이 MLOps 프로젝트 코드 저장소 폴더의 `pipelines` 폴더에 복사됩니다.
# - 노트북 3에서 생성된 `requirements.txt`가 `pipelines` 폴더에 복사됩니다.
# - 노트북 3의 SageMaker Python SDK 기본 설정 파일 `config.yaml`이 `pipelines` 폴더에 복사됩니다.

# %%
# see the workshop folder name
# !pwd

# %%
# if you local path for the workshop folder is different, set the correct absolute path to the variable workshop_folder
workshop_folder = "amazon-sagemaker-from-idea-to-production"

# %%
# !mkdir -p ~/{workshop_folder}/pipelines
# !mv ~/{project_path}/codebuild-buildspec.yml ~/{project_path}/codebuild-buildspec-original.yml
# !mv ~/{project_path}/setup.py ~/{project_path}/setup-original.py
# !mv ~/{project_path}/pipelines/abalone ~/{project_path}/pipelines/fromideatoprod
# !mv ~/{project_path}/pipelines/fromideatoprod/pipeline.py ~/{project_path}/pipelines/fromideatoprod/pipeline-original.py
# !cp ~/{workshop_folder}/pipeline_steps/* ~/{project_path}/pipelines/
# !cp ~/{workshop_folder}/pipeline_steps/* ~/{workshop_folder}/pipelines/
# !cp ~/{workshop_folder}/requirements.txt ~/{project_path}
# !cp ~/{workshop_folder}/config.yaml ~/{project_path}

# %% [markdown]
# 다음 셀을 실행하여 파이프라인 구성 코드를 `pipeline.py` 파일에 작성합니다. 3단계 노트북의 코드를 `get_pipeline()` 함수로 재사용합니다.
#
# <div style="border: 4px solid coral; text-align: center; margin: auto;">
#     <p style=" text-align: center; margin: auto;">파이프라인 구성 코드는 S3 원시 입력 데이터셋 또는 피처 스토어의 피처 세트 모두와 작동합니다. 파이프라인에 해당 입력 파라미터를 전달해야 합니다.
#     </p>
# </div>

# %%
# %%writefile pipeline.py

import json
import os
import boto3
import mlflow
from time import gmtime, strftime
from importlib.metadata import version

# V3: Core imports
from sagemaker.core.helper.session_helper import Session, get_execution_role
from sagemaker.core import image_uris
from sagemaker.core.workflow.parameters import ParameterString, ParameterFloat
from sagemaker.core.workflow.conditions import ConditionGreaterThanOrEqualTo
from sagemaker.core.workflow.functions import Join
from sagemaker.core.workflow.execution_variables import ExecutionVariables
from sagemaker.core.workflow.pipeline_context import PipelineSession
from sagemaker.core.workflow.pipeline_definition_config import PipelineDefinitionConfig

# V3: Pipeline imports
from sagemaker.mlops.workflow.pipeline import Pipeline
from sagemaker.mlops.workflow.steps import CacheConfig
from sagemaker.mlops.workflow.fail_step import FailStep
from sagemaker.mlops.workflow.condition_step import ConditionStep
from sagemaker.mlops.workflow.function_step import step

from pipelines.preprocess import preprocess
from pipelines.train_fn import train
from pipelines.evaluate import evaluate
from pipelines.register import register


def get_sagemaker_client(region):
    return boto3.Session(region_name=region).client("sagemaker")


def get_pipeline_custom_tags(new_tags, region, sagemaker_project_name=None):
    try:
        sm_client = get_sagemaker_client(region)
        project_arn = sm_client.describe_project(ProjectName=sagemaker_project_name)["ProjectArn"]
        project_tags = sm_client.list_tags(ResourceArn=project_arn)["Tags"]
        for project_tag in project_tags:
            new_tags.append(project_tag)
    except Exception as e:
        print(f"Error getting project tags: {e}")
    return new_tags


def get_pipeline(
    region,
    sagemaker_project_id=None,
    sagemaker_project_name=None,
    role=None,
    bucket_name=None,
    bucket_prefix="from-idea-to-prod/xgboost",
    input_s3_url=None,
    model_package_group_name="from-idea-to-prod-model-group",
    pipeline_name_prefix="from-idea-to-prod-pipeline",
    process_instance_type="ml.r5.xlarge",
    train_instance_type="ml.r5.xlarge",
    test_score_threshold=0.70,
    tracking_server_arn=None,
):
    """Gets a SageMaker ML Pipeline instance using @step decorator (V3).
    
    MLflow tracking URI and experiment name are passed via config.yaml
    EnvironmentVariables — the step functions read them from the environment.
    """

    sm = boto3.Session(region_name=region).client("sagemaker")

    if role is None:
        role = get_execution_role()

    print(f"sagemaker version: {version('sagemaker')}")
    print(f"Execution role: {role}")
    print(f"Input S3 URL: {input_s3_url}")

    pipeline_name = f"{pipeline_name_prefix}-{sagemaker_project_id}"
    experiment_name = pipeline_name

    output_s3_prefix = f"s3://{bucket_name}/{bucket_prefix}"
    output_s3_url = f"{output_s3_prefix}/output"

    # Discover MLflow app if not provided
    if tracking_server_arn is None:
        summaries = []
        for status in ["Created", "Updated"]:
            r = sm.list_mlflow_apps(Status=status)
            summaries.extend(r["Summaries"])
        if len(summaries) < 1:
            print("No running MLflow apps found. Exiting...")
            return None
        tracking_server_arn = summaries[0]["Arn"]
        print(f"Using MLflow app: {tracking_server_arn}")

    # Pipeline parameters
    process_instance_type_param = ParameterString(name="ProcessingInstanceType", default_value=process_instance_type)
    train_instance_type_param = ParameterString(name="TrainingInstanceType", default_value=train_instance_type)
    model_approval_status_param = ParameterString(name="ModelApprovalStatus", default_value="PendingManualApproval")
    test_score_threshold_param = ParameterFloat(name="TestScoreThreshold", default_value=test_score_threshold)
    input_s3_url_param = ParameterString(name="InputDataUrl", default_value=input_s3_url if input_s3_url else "None")
    model_package_group_name_param = ParameterString(name="ModelPackageGroupName", default_value=model_package_group_name)

    cache_config = CacheConfig(enable_caching=True, expire_after="P30d")

    # Preprocess step
    step_get_datasets = step(
        preprocess,
        role=role,
        instance_type=process_instance_type_param,
        name="preprocess",
        keep_alive_period_in_seconds=3600,
    )(
        input_data_s3_path=input_s3_url_param,
        output_s3_prefix=output_s3_prefix,
        pipeline_run_name=ExecutionVariables.PIPELINE_EXECUTION_ID,
    )

    # Train step
    step_train = step(
        train,
        role=role,
        instance_type=train_instance_type_param,
        name="train",
        keep_alive_period_in_seconds=3600,
    )(
        train_data_s3_path=step_get_datasets["train_data"],
        validation_data_s3_path=step_get_datasets["validation_data"],
        output_s3_prefix=output_s3_prefix,
        pipeline_run_id=step_get_datasets["pipeline_run_id"],
    )

    # Evaluate step
    step_evaluate = step(
        evaluate,
        role=role,
        instance_type=process_instance_type_param,
        name="evaluate",
        keep_alive_period_in_seconds=3600,
    )(
        test_x_data_s3_path=step_get_datasets["test_x_data"],
        test_y_data_s3_path=step_get_datasets["test_y_data"],
        model_s3_path=step_train["model_s3_path"],
        output_s3_prefix=output_s3_prefix,
        pipeline_run_id=step_get_datasets["pipeline_run_id"],
    )

    # Register step — uses mlflow.register_model() with auto-sync to SageMaker
    step_register = step(
        register,
        role=role,
        instance_type=process_instance_type_param,
        name="register",
        keep_alive_period_in_seconds=3600,
    )(
        model_package_group_name=model_package_group_name_param,
        model_approval_status=model_approval_status_param,
        evaluation_result=step_evaluate["evaluation_result"],
        mlflow_run_id=step_train["mlflow_run_id"],
        training_job_name=step_train["training_job_name"],
        pipeline_run_id=step_get_datasets["pipeline_run_id"],
    )

    # Fail step
    step_fail = FailStep(
        name="fail",
        error_message=Join(on=" ", values=["Execution failed due to AUC Score <", test_score_threshold_param]),
    )

    # Condition step
    step_conditional_register = ConditionStep(
        name="check-metrics",
        conditions=[ConditionGreaterThanOrEqualTo(
            left=step_evaluate["evaluation_result"]["classification_metrics"]["auc_score"]["value"],
            right=test_score_threshold_param,
        )],
        if_steps=[step_register],
        else_steps=[step_fail],
    )

    # Create pipeline
    pipeline = Pipeline(
        name=pipeline_name,
        parameters=[
            input_s3_url_param,
            process_instance_type_param,
            train_instance_type_param,
            model_approval_status_param,
            test_score_threshold_param,
            model_package_group_name_param,
        ],
        steps=[step_conditional_register],
        pipeline_definition_config=PipelineDefinitionConfig(use_custom_job_prefix=True),
    )

    return pipeline

# %% [markdown]
# 이 `pipeline.py` 파일을 워크샵 폴더에서 프로젝트 코드 저장소 폴더의 `pipelines/fromideatoprod` 폴더로 복사합니다:

# %%
# !cp ~/{workshop_folder}/pipeline.py ~/{project_path}/pipelines/fromideatoprod/

# %% [markdown]
# `get_pipeline` 함수를 로컬에서 테스트하여 원격으로 실행하기 전에 모든 것이 작동하는지 확인합니다.

# %%
import importlib
import pipeline
importlib.reload(pipeline)
from pipeline import get_pipeline

# %%
input_s3_url = s3_data_uri

# %%
target_model_package_group_name

# %%
p = get_pipeline(
    region=region,
    sagemaker_project_id=project_id,
    sagemaker_project_name=project_name,
    role=sm_role,
    bucket_name=bucket_name,
    bucket_prefix=bucket_prefix,
    input_s3_url=input_s3_url,
    model_package_group_name=model_package_group_name,
    pipeline_name_prefix=pipeline_name,
    process_instance_type="ml.r5.xlarge",
    train_instance_type="ml.r5.xlarge",
    test_score_threshold=0.70,
    tracking_server_arn=mlflow_arn,
)

# %%
model_package_group_name

# %%
p.definition()

# %%
p.upsert(role_arn=sm_role)

# %% [markdown]
# 생성된 파이프라인을 Studio UI에서 보려면 아래 코드 셀로 구성된 링크를 클릭합니다:

# %%
from IPython.display import HTML

# Show the pipeline link
display(
    HTML('<b>See <a target="top" href="https://studio-{}.studio.{}.sagemaker.aws/pipelines/{}/graph">the pipeline</a> in the Studio UI</b>'.format(
            domain_id, region, p.describe()['PipelineName']))
)

# %% [markdown]
# 이 시점에서 파이프라인 구성 코드가 작동하고 파이프라인을 생성한다는 것을 로컬에서 테스트했습니다. Studio **파이프라인** 위젯에서 이 파이프라인을 볼 수 있습니다. 이제 CI/CD 파이프라인을 생성할 준비가 되었습니다.

# %% [markdown]
# #### 리소스 태그로 프로젝트 소유권 제어
# 프로젝트 소유 리소스는 비용 제어, 속성 기반 보안 제어, 거버넌스를 위해 `sagemaker:project-name` 및 `sagemaker:project-id` 태그로 자동 태그가 지정됩니다.
#
# 기존 저장소, 파이프라인, 모델 레지스트리 그룹 또는 엔드포인트를 프로젝트에 연결해야 하는 경우, 프로젝트 이름과 ID가 포함된 이 두 태그를 리소스에 추가할 수 있습니다.

# %%
target_model_package_group_name

# %%
# Tag the model package group with project tags (if it exists)
# The group is auto-created when the pipeline registers a model via MLflow
try:
    model_package_group_arn = sm.describe_model_package_group(
        ModelPackageGroupName=target_model_package_group_name
    ).get('ModelPackageGroupArn')
    
    print(f'Adding project tags to {model_package_group_arn}')
    sm.add_tags(
        ResourceArn=model_package_group_arn,
        Tags=[
            {'Key': 'sagemaker:project-name', 'Value': project_name},
            {'Key': 'sagemaker:project-id', 'Value': project_id},
        ]
    )
except Exception as e:
    print(f'Model package group not found yet — it will be created when the pipeline runs.')
    print(f'You can re-run this cell after the pipeline completes.')

# %% [markdown]
# ### 3. 빌드 사양 파일 수정
# 이제 프로젝트 폴더의 `codebuild-buildspec.yml` 파일을 수정하여 파이프라인이 포함된 Python 모듈의 새 이름을 반영하고 기타 프로젝트별 파라미터를 설정합니다.

# %% [markdown]
# 파이프라인 생성 스크립트에 다음 파라미터를 전달해야 합니다:
# - `input_s3_url` - 입력 원시 데이터셋의 S3 URL
# - `model_package_group_name` – 훈련 후 모델을 등록할 모델 레지스트리 패키지
# - `pipeline_name_prefix` – 파이프라인의 이름 접두사
# - `role` – 파이프라인 실행 역할
# - `tracking_server_arn` - 파이프라인 실행 추적을 위한 MLflow 서버 ARN

# %% [markdown]
# 빌드 사양 파일은 CodeBuild에 의존성을 설치하고 파이프라인을 실행하는 방법을 알려줍니다. 두 가지 유형의 설정이 필요합니다:
#
# - **정적 값** (S3 경로, IAM 역할, MLflow ARN) — 노트북 시간에 알려지며 `pipeline_kwargs.json`에 저장됩니다
# - **동적 값** (AWS 리전, 프로젝트 이름/ID, 아티팩트 버킷) — 런타임에 CodeBuild가 환경 변수로 제공합니다

# %%
import json as _json

# Static kwargs — values known at notebook time
static_kwargs = {
    'input_s3_url': s3_data_uri,
    'model_package_group_name': model_package_group_name,
    'pipeline_name_prefix': pipeline_name,
    'role': sm_role,
    'tracking_server_arn': mlflow_arn,
}

# Write static kwargs to a JSON file — CodeBuild will merge in dynamic values
with open('pipeline_kwargs.json', 'w') as f:
    _json.dump(static_kwargs, f)

# Buildspec calls a helper script that merges static + dynamic kwargs
buildspec = '''version: 0.2

phases:
  install:
    runtime-versions:
      python: 3.10
    commands:
      - pip install --upgrade --force-reinstall . --extra-index-url https://download.pytorch.org/whl/cpu

  build:
    commands:
      - export SAGEMAKER_USER_CONFIG_OVERRIDE="./config.yaml"
      - export PYTHONUNBUFFERED=TRUE
      - export SAGEMAKER_PROJECT_NAME_ID="${SAGEMAKER_PROJECT_NAME}-${SAGEMAKER_PROJECT_ID}"
      - |
        python -c "
        import json, subprocess, sys
        import os
        kwargs = json.load(open('pipeline_kwargs.json'))
        kwargs['region'] = os.environ['AWS_REGION']
        kwargs['sagemaker_project_name'] = os.environ['SAGEMAKER_PROJECT_NAME']
        kwargs['sagemaker_project_id'] = os.environ['SAGEMAKER_PROJECT_ID']
        kwargs['bucket_name'] = os.environ['ARTIFACT_BUCKET']
        cmd = [
            'run-pipeline',
            '--module-name', 'pipelines.fromideatoprod.pipeline',
            '--role-arn', os.environ['SAGEMAKER_PIPELINE_ROLE_ARN'],
            '--tags', json.dumps([
                {'Key': 'sagemaker:project-name', 'Value': os.environ['SAGEMAKER_PROJECT_NAME']},
                {'Key': 'sagemaker:project-id', 'Value': os.environ['SAGEMAKER_PROJECT_ID']},
            ]),
            '--kwargs', json.dumps(kwargs),
        ]
        sys.exit(subprocess.call(cmd))
        "
      - echo "Create/update of the SageMaker Pipeline and a pipeline execution completed."
'''

with open('codebuild-buildspec.yml', 'w') as f:
    f.write(buildspec)

print('codebuild-buildspec.yml and pipeline_kwargs.json written')
print(f'Static kwargs: {_json.dumps(static_kwargs, indent=2)}')

# %% [markdown]
# 워크샵 폴더에서 프로젝트 코드 저장소 폴더로 `codebuild-buildspec.yml` 파일을 복사합니다:

# %%
# !cp ~/{workshop_folder}/codebuild-buildspec.yml ~/{project_path}/codebuild-buildspec.yml
# !cp ~/{workshop_folder}/pipeline_kwargs.json ~/{project_path}/pipeline_kwargs.json

# %% [markdown]
# 요약하면, 빌드 사양 파일에서 세 가지 변경을 했습니다:
# 1. `run-pipeline`의 `--module-name` 파라미터 값을 `pipelines.abalone.pipeline`에서 새 경로 `pipelines.fromideatoprod.pipeline`으로 수정
# 2. `get_pipeline()` 함수의 기본 파라미터 값을 활용하기 위해 `kwargs` 목록에서 일부 파라미터 제거
# 3. `kwargs` 파라미터 목록에 파이프라인을 위한 추가 파라미터 추가

# %% [markdown]
# ### 4. `setup.py` 파일 생성
# 마지막으로 프로젝트 코드 저장소 폴더에 `setup.py` 파일을 제공해야 합니다.

# %%
# %%writefile setup.py
import os
import setuptools


about = {}
here = os.path.abspath(os.path.dirname(__file__))
with open(os.path.join(here, "pipelines", "__version__.py")) as f:
    exec(f.read(), about)


with open("README.md", "r") as f:
    readme = f.read()


required_packages = [
    "sagemaker-core==2.7.1",
    "sagemaker-train==1.7.1",
    "sagemaker-serve==1.7.1",
    "sagemaker-mlops==1.7.1",
    "sagemaker==3.7.1",
    "mlflow<4",
    "sagemaker-mlflow==0.2.0",
    "s3fs",
    "xgboost==3.0.5"
]
extras = {
    "test": [
        "black",
        "coverage",
        "flake8",
        "mock",
        "pydocstyle",
        "pytest",
        "pytest-cov",
        "sagemaker",
        "tox",
    ]
}
setuptools.setup(
    name=about["__title__"],
    description=about["__description__"],
    version=about["__version__"],
    author=about["__author__"],
    author_email=["__author_email__"],
    long_description=readme,
    long_description_content_type="text/markdown",
    url=about["__url__"],
    license=about["__license__"],
    packages=setuptools.find_packages(),
    include_package_data=True,
    python_requires=">=3.10",
    install_requires=required_packages,
    extras_require=extras,
    entry_points={
        "console_scripts": [
            "get-pipeline-definition=pipelines.get_pipeline_definition:main",
            "run-pipeline=pipelines.run_pipeline:main",
        ]
    },
    classifiers=[
        "Development Status :: 3 - Alpha",
        "Intended Audience :: Developers",
        "Natural Language :: English",
        "Programming Language :: Python",
        "Programming Language :: Python :: 3.8",
        "Programming Language :: Python :: 3.9",
        "Programming Language :: Python :: 3.10",
    ]
)

# %%
# !cp ~/{workshop_folder}/setup.py ~/{project_path}/setup.py

# %% [markdown]
# ---

# %% [markdown]
# ## 모델 빌드 파이프라인을 위한 CI/CD 실행
# 모델 빌드 파이프라인을 위한 CI/CD를 시작하려면 변경된 코드를 프로젝트 GitHub 저장소에 푸시해야 합니다.
#
# <div class="alert alert-info">git 명령을 실행할 때 JupyterLab 터미널에서 저장소 코드가 포함된 폴더에 있는지 확인하세요. 폴더 이름은 <code>[project-name]/sagemaker-[project-id]-modelbuild</code>와 같습니다.</div>
#
# JupyterLab 메뉴 **File** > **New** > **Terminal**을 통해 시스템 터미널 창을 열고 다음 코드 셀로 생성된 명령을 입력합니다.

# %%
cmd = f'''
cd ~/{project_path}

git config --global user.email "you@example.com"
git config --global user.name "Your Name"
  
git add -A
git commit -am "customize project"
git push
'''

copy_output(cmd)

# %% [markdown]
# 코드 변경 사항을 푸시한 후, 프로젝트는 SageMaker 모델 빌드 파이프라인을 구성, 업서트, 실행하는 CodePipeline 파이프라인 실행을 시작합니다. 이 새 파이프라인 실행은 SageMaker 모델 레지스트리의 모델 패키지 그룹에 새 모델 버전을 생성합니다.
#
# Studio **파이프라인** 위젯에서 파이프라인 실행을 추적할 수 있습니다.
#
# 파이프라인 실행이 완료될 때까지 기다립니다. 실행은 약 10분 정도 소요됩니다.

# %% [markdown]
# 파이프라인 실행을 보려면 아래 코드 셀로 구성된 링크를 클릭합니다. CodeBuild가 파이프라인을 업서트하고 실행을 시작하는 데 약 1분이 소요됩니다. Studio UI 페이지를 새로고침하여 시작된 실행을 확인합니다.

# %%
# Show the pipeline execution link
display(
    HTML('<b>See <a target="top" href="https://studio-{}.studio.{}.sagemaker.aws/pipelines/{}/executions/">the pipeline executions</a> in the Studio UI</b>'.format(
            domain_id, region, p.describe()['PipelineName']))
)

# %% [markdown]
# ## 모델 레지스트리에서 모델 패키지 보기
#
# 파이프라인은 `mlflow.register_model()`을 통해 모델을 등록합니다. MLflow 앱에서 `AutoModelRegistrationEnabled`가 활성화되어 있으므로, 이는 자동으로 SageMaker 모델 패키지 그룹을 생성합니다.
#
# 다음 셀은 자동 생성된 그룹 이름을 찾아 노트북 05에서 배포에 사용할 수 있도록 합니다.

# %%
# Show the model package link
display(
    HTML('<b>See <a target="top" href="https://studio-{}.studio.{}.sagemaker.aws/registry/registered-models/{}/versions">the model package versions</a> in the Studio UI</b>'.format(
            domain_id, region, target_model_package_group_name))
)

# %%
# import time

# # Wait for the pipeline to complete and register the model
# print("Waiting for the pipeline to register a model...")
# print("This may take 15-20 minutes. Check the pipeline execution in the Studio UI.")

# model_package_group_name = None
# mlflow_model_name = target_model_package_group_name #f"{project_name}-{project_id}"

# while model_package_group_name is None:
#     groups = sm.list_model_package_groups(
#         NameContains=mlflow_model_name
#     )["ModelPackageGroupSummaryList"]
    
#     for g in groups:
#         pkgs = sm.list_model_packages(ModelPackageGroupName=g["ModelPackageGroupName"])
#         if pkgs["ModelPackageSummaryList"]:
#             target_model_package_group_name = g["ModelPackageGroupName"]
#             break
    
#     if model_package_group_name is None:
#         time.sleep(60)
#         print(".", end="", flush=True)

# print(f"\nDiscovered SageMaker Model Package Group: {model_package_group_name}")
# %store target_model_package_group_name

# %% [markdown]
# ### 배포 트리거 설정
#
# 프로젝트 생성 시 `ModelPackageGroupName`을 파라미터로 전달했으므로, EventBridge 규칙과 배포 CodeBuild 프로젝트는 이미 올바른 자동 동기화된 모델 패키지 그룹을 감시하도록 설정되어 있습니다. CloudFormation 템플릿이 이를 자동으로 처리하므로 수동 패치가 필요 없습니다.

# %% [markdown]
# ## 요약
# 이 노트북에서 다음 기능을 갖춘 CI/CD 파이프라인을 구현했습니다:
# - 모델 빌드 ML 파이프라인이 GitHub 저장소의 소스 제어 하에 있음
# - 코드 저장소에 푸시할 때마다 ML 파이프라인을 구성, 업서트, 실행하는 새 CodePipeline 파이프라인이 시작됨
# - 전체 엔드투엔드 모델 개발 프로세스가 자동화됨
# - SageMaker 프로젝트는 관련 ML 파이프라인, 저장소, 모델, 실험, 추론 엔드포인트에 대한 메타데이터를 가진 Studio의 논리적 구성체
#
# ---

# %% [markdown]
# ## 5단계 계속하기
# 다음 노트북 [05-deploy](05-deploy.ipynb)에서 MLOps 프로젝트의 두 번째 부분인 모델 배포 파이프라인을 테스트합니다.

# %% [markdown]
# ## 실제 프로젝트를 위한 추가 개발 아이디어
# - [Jenkins를 사용한 타사 Git 저장소로 모델 빌드, 훈련, 배포를 위한 SageMaker 제공 MLOps 템플릿](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-projects-templates-sm.html#sagemaker-projects-templates-git-jenkins)을 사용할 수 있습니다
# - 특정 프로젝트 요구사항을 충족하는 [커스텀 SageMaker 프로젝트 템플릿](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-projects-templates-custom.html)을 생성하세요

# %% [markdown]
# ## 추가 리소스
# - [SageMaker 이머전 데이의 Amazon SageMaker Pipelines 실습](https://catalog.us-east-1.prod.workshops.aws/workshops/63069e26-921c-4ce1-9cc7-dd882ff62575/en-US/lab6)
# - [Amazon SageMaker 프로젝트를 사용한 모듈식 아키텍처로 머신러닝 개발 향상](https://aws.amazon.com/blogs/machine-learning/enhance-your-machine-learning-development-by-using-a-modular-architecture-with-amazon-sagemaker-projects/)
# - [MLOps 자동화 심층 분석](https://www.youtube.com/watch?v=3_cHnk9VSfQ)
# - [SageMaker MLOps 프로젝트 연습](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-projects-walkthrough.html)
# - [커스텀 프로젝트 템플릿 예제가 있는 `aws-samples` GitHub 저장소](https://github.com/aws-samples/sagemaker-custom-project-templates)

# %% [markdown]
# # 커널 종료

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
