# %% [markdown]
# # 2단계: SageMaker AI 처리 및 훈련 작업 추가
#
# <div style="border: 2px solid #ff9900; border-radius: 8px; padding: 15px; background-color: #fff3e0; margin-bottom: 10px;">
# <strong>⚠️ 호환성 안내:</strong> 이 노트북은 <strong>SageMaker Distribution Image 4.0.0</strong> 및 <strong>SageMaker Python SDK 버전 3.7.1</strong>에서 테스트되었습니다.
# </div>
#
# 이 단계에서는 데이터 처리와 모델 훈련을 [SageMaker Docker 컨테이너](https://docs.aws.amazon.com/sagemaker/latest/dg/docker-containers.html)로 이동하고 [SageMaker Python SDK](https://sagemaker.readthedocs.io/en/stable/index.html)를 사용하여 SageMaker와 상호작용합니다.
#
# ||||
# |---|---|---|
# |1. |노트북에서 실험하기 ||
# |2. |SageMaker AI 처리 작업과 SageMaker SDK로 확장하기 |**<<<< 현재 위치**|
# |3. |ML 파이프라인, 모델 레지스트리로 운영화하기 ||
# |4. |모델 빌드 CI/CD 파이프라인 추가하기 ||
# |5. |모델 배포 파이프라인 추가하기 ||
# |6. |모델 및 데이터 모니터링 추가하기 ||
#
# SageMaker는 Docker 컨테이너를 활용하여 개발자가 데이터를 처리하고 모델을 훈련 및 배포할 수 있게 합니다. 컨테이너는 Docker를 지원하는 모든 플랫폼에서 일관되게 실행되는 표준화된 단위로 소프트웨어를 패키징할 수 있게 해줍니다.
#
# SageMaker는 인기 있는 데이터 처리 프레임워크와 ML 알고리즘을 위한 사전 빌드된 컨테이너도 제공하며, 모든 SageMaker 내장 알고리즘은 Docker 컨테이너로 제공됩니다.
#
# SageMaker에서 훈련을 실행하는 세 가지 방법을 점진적으로 배웁니다:
# 1. **`@remote` 데코레이터** — 가장 간단한 방법: Python 함수에 어노테이션을 달면 SageMaker 작업으로 실행됩니다
# 2. **로컬 모드의 `ModelTrainer`** — 제출 전에 로컬 Docker 컨테이너에서 훈련 스크립트를 테스트합니다
# 3. **관리형 인프라의 `ModelTrainer`** — SageMaker 관리 인스턴스에서 대규모로 실행합니다
#
# 동일한 로컬 → 원격 패턴이 `FrameworkProcessor`를 사용한 데이터 처리에도 적용됩니다.

# %% [markdown]
# <div style="border: 4px solid #d32f2f; border-radius: 10px; padding: 20px; background-color: #ffebee; margin: 15px 0;">
#
# ### ⛔ 중요: Python 3.10 필수
#
# 이 워크샵의 모든 노트북은 **Python 3.10**에서 실행해야 합니다. 다른 Python 버전을 사용하면 아래 셀이 `AssertionError`로 실패합니다.
#
# 오류가 발생하면 다음 단계를 따르세요:
#
# 1. JupyterLab에서 **터미널**을 엽니다 (**File → New → Terminal**)
# 2. 설정 스크립트를 실행합니다:
#    ```bash
#    cd ~/amazon-sagemaker-from-idea-to-production
#    ./setup-py310.sh
#    ```
# 3. 새 커널을 적용하려면 **브라우저를 새로고침**합니다
# 4. 이 노트북에서 **Kernel → Change Kernel → Python 3.10**으로 이동합니다
# 5. **커널을 재시작**하고 처음부터 다시 실행합니다
#
# </div>

# %%
import sys

assert sys.version_info[:2] == (3, 10), f"Expected Python 3.10, got {sys.version_info.major}.{sys.version_info.minor}. Please make sure you run on Python 3.10"

# %% [markdown]
# 이전 노트북에서 저장된 변수를 로드합니다.

# %%
# %store -r 

# %store

try:
    initialized
except NameError:
    print("+++++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN 00-start-here notebook   ")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++")

# %%
import warnings
import os
from io import StringIO
from IPython.display import HTML
import tarfile
import tempfile
from urllib.parse import urlparse
import boto3
import mlflow
import pandas as pd
import xgboost as xgb
import numpy as np
from numpy import loadtxt
from sklearn.metrics import roc_auc_score, RocCurveDisplay
from sklearn import metrics
import matplotlib.pyplot as plt

from sagemaker.core.utils.utils import configure_logging
from sagemaker.core.common_utils import name_from_base
from sagemaker.core.s3 import S3Downloader
from sagemaker.core.s3.client import s3_path_join
from sagemaker.core.shapes import ProcessingInput, ProcessingS3Input, ProcessingOutput, ProcessingS3Output, OutputDataConfig
from sagemaker.core import FrameworkProcessor
from sagemaker.core.local import LocalSession
from sagemaker.core.helper.session_helper import Session
from sagemaker.core.image_uris import retrieve
from sagemaker.core.remote_function.client import remote
from sagemaker.train.configs import InputData, SourceCode, Compute
from sagemaker.train import ModelTrainer
from sagemaker.serve.model_builder import ModelBuilder

# %%
warnings.filterwarnings('ignore')
configure_logging('INFO')

# %% [markdown]
# ## MLflow 실험 준비
# 이전 노트북에서 생성한 기존 실험을 재사용합니다. 동일한 실험에서 새 실행을 추적합니다.
# 이 노트북의 실행을 추적하기 위해 새 실험을 생성할 수도 있습니다 — 이 경우 다음 코드 셀의 주석을 해제하세요.

# %%
# Uncomment code block (Cmd + /) if you would like to create a new experiment

# experiment_name = name_from_base("from-idea-to-prod-experiment-", short=True)

# %%
mlflow.set_tracking_uri(mlflow_arn)
experiment = mlflow.set_experiment(experiment_name=experiment_name)
print(f'Using MLflow server: {mlflow_arn}')

# %% [markdown]
# ## SageMaker Processing Job으로 데이터 처리
# Python 스크립트를 제공하고 [SageMaker SDK 프로세서](https://sagemaker.readthedocs.io/en/stable/api/sagemaker_core.html#module-sagemaker.core.processing) 클래스를 선택하여 [SageMaker Processing](https://docs.aws.amazon.com/sagemaker/latest/dg/processing-job.html)을 사용합니다.
#
# 입력 데이터를 S3에 업로드하고 출력 데이터의 S3 위치를 지정할 수 있습니다. SageMaker Processing은 S3에서 입력 데이터를 자동으로 로드하고 작업이 완료되면 변환된 데이터를 S3에 다시 업로드합니다. 처리 컨테이너 이미지는 Amazon SageMaker 내장 이미지 또는 직접 제공하는 커스텀 이미지일 수 있습니다.
#
# ![](img/sagemaker-processing.png)

# %% [markdown]
# 이 섹션에서는 SageMaker 관리 인프라로 이동하기 전에 데이터 처리 작업을 로컬에서 테스트하는 방법을 보여줍니다.

# %% [markdown]
# ### SageMaker 프레임워크 컨테이너에서 처리 스크립트 로컬 실행
# SageMaker 내장 관리 컨테이너에서 로컬 모드로 데이터 처리 스크립트를 실행하는 것부터 시작합니다. [로컬 모드](https://docs.aws.amazon.com/sagemaker/latest/dg/studio-updated-local.html)를 사용하면 원격 컴퓨팅 인스턴스를 생성하지 않고 로컬 개발 환경에서 SageMaker 작업을 실행할 수 있습니다.
#
# <div class="alert alert-info">노트북 00에서 Docker를 설치했는지 확인하세요. 로컬 처리를 건너뛰고 원격으로 작업을 실행하는 다음 섹션으로 바로 이동할 수도 있습니다.</div>

# %% [markdown]
# 처리 코드와 요구사항을 저장할 폴더를 생성합니다. 처리 스크립트에서 MLflow를 사용하므로, 컨테이너가 처리 스크립트를 실행하기 전에 mlflow와 MLflow SageMaker 플러그인을 설치할 수 있도록 `requirements.txt`를 제공해야 합니다.

# %%
local_processing_dir = "./processing/"
os.makedirs(local_processing_dir, exist_ok=True)
with open(os.path.join(local_processing_dir, "requirements.txt"), "w") as file_handle:
    file_handle.write("mlflow>3\nsagemaker-mlflow\n")

# %% [markdown]
# 노트북 01의 데이터 처리 코드를 .py 파일로 이동하고 MLflow로 실험 추적을 추가하여 Python 스크립트를 생성합니다.

# %%
# %%writefile processing/preprocessing.py
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import pandas as pd
import numpy as np
import argparse
import os

from time import gmtime, strftime, sleep
import traceback

user_profile_name = os.getenv('USER')
print(os.environ)
def _parse_args():
    
    parser = argparse.ArgumentParser()
    # Data, model, and output directories
    # model_dir is always passed in from SageMaker. By default this is a S3 path under the default bucket.
    parser.add_argument('--filepath', type=str, default='/opt/ml/processing/input/')
    parser.add_argument('--filename', type=str, default='bank-additional-full.csv')
    parser.add_argument('--outputpath', type=str, default='/opt/ml/processing/output/')
    
    return parser.parse_known_args()

def process_data(df_data):
    # Indicator variable to capture when pdays takes a value of 999
    df_data["no_previous_contact"] = np.where(df_data["pdays"] == 999, 1, 0)

    # Indicator for individuals not actively employed
    df_data["not_working"] = np.where(
        np.in1d(df_data["job"], ["student", "retired", "unemployed"]), 1, 0
    )

    # remove unnecessary data
    df_model_data = df_data.drop(
        ["duration", "emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed"],
        axis=1,
    )

    bins = [18, 30, 40, 50, 60, 70, 90]
    labels = ['18-29', '30-39', '40-49', '50-59', '60-69', '70-plus']

    df_model_data['age_range'] = pd.cut(df_model_data.age, bins, labels=labels, include_lowest=True)
    df_model_data = pd.concat([df_model_data, pd.get_dummies(df_model_data['age_range'], prefix='age', dtype=int)], axis=1)
    df_model_data.drop('age', axis=1, inplace=True)
    df_model_data.drop('age_range', axis=1, inplace=True)

    scaled_features = ['pdays', 'previous', 'campaign']
    df_model_data[scaled_features] = MinMaxScaler().fit_transform(df_model_data[scaled_features])

    df_model_data = pd.get_dummies(df_model_data, dtype=int)  # Convert categorical variables to sets of indicators

    # Replace "y_no" and "y_yes" with a single label column, and bring it to the front:
    df_model_data = pd.concat(
        [
            df_model_data["y_yes"].rename(target_col),
            df_model_data.drop(["y_no", "y_yes"], axis=1),
        ],
        axis=1,
    )
    
    return df_model_data

if __name__=="__main__":
    # Process arguments
    args, _ = _parse_args()
    
    target_col = "y"
    
    import mlflow
    
    # Set the Tracking Server URI using the ARN of the Tracking Server you created
    mlflow.set_tracking_uri(os.environ['MLFLOW_TRACKING_ARN'])
    
    # Enable autologging in MLflow
    mlflow.autolog()

    # Use the active run_id to log 
    with mlflow.start_run(run_id=os.environ['MLFLOW_RUN_ID']) as run:
        # process data
        df_model_data = process_data(pd.read_csv(os.path.join(args.filepath, args.filename), sep=";"))
    
        # Shuffle and splitting dataset
        train_data, validation_data, test_data = np.split(
            df_model_data.sample(frac=1, random_state=1729),
            [int(0.7 * len(df_model_data)), int(0.9 * len(df_model_data))],
        )
    
        print(f"Data split > train:{train_data.shape} | validation:{validation_data.shape} | test:{test_data.shape}")
        mlflow.log_params(
            {
                "train": train_data.shape,
                "validate": validation_data.shape,
                "test": test_data.shape
            }
        )

        mlflow.set_tags(
            {
                'mlflow.user':user_profile_name,
                'mlflow.source.type':'JOB'
            }
        )
        
        # Save datasets locally
        train_data.to_csv(os.path.join(args.outputpath, 'train/train.csv'), index=False, header=False)
        validation_data.to_csv(os.path.join(args.outputpath, 'validation/validation.csv'), index=False, header=False)
        test_data[target_col].to_csv(os.path.join(args.outputpath, 'test/test_y.csv'), index=False, header=False)
        test_data.drop([target_col], axis=1).to_csv(os.path.join(args.outputpath, 'test/test_x.csv'), index=False, header=False)
        
        # Save the baseline dataset for model monitoring
        df_model_data.drop([target_col], axis=1).to_csv(os.path.join(args.outputpath, 'baseline/baseline.csv'), index=False, header=False)

        mlflow.log_artifact(local_path=os.path.join(args.outputpath, 'baseline/baseline.csv'))

        mlflow.log_artifact(local_path=os.path.join(args.outputpath, "train/train.csv"))
        mlflow.log_artifact(local_path=os.path.join(args.outputpath, "validation/validation.csv"))
        mlflow.log_artifact(local_path=os.path.join(args.outputpath, "test/test_x.csv"))
        mlflow.log_artifact(local_path=os.path.join(args.outputpath, "test/test_y.csv"))
    
    print("## Processing complete. Exiting.")

# %% [markdown]
# 처리 스크립트에는 헤더와 레이블 컬럼 없이 전체 데이터셋을 기준 데이터셋으로 저장하는 구문이 포함되어 있습니다. 이 데이터 기준은 나중에 모델 모니터링 노트북에서 필요합니다.

# %% [markdown]
# #### 실험 실행 생성
# 처리 작업의 파라미터, 설정, 입력, 출력을 추적하기 위해 실험에 새 실행을 생성합니다.

# %%
run_name = name_from_base("container-processing-", short=True)
run_id = mlflow.start_run(
    run_name=run_name,
    description="feature-engineering in the notebook 02 with a processing job").info.run_id

# %% [markdown]
# #### 프로세서 생성 및 입출력 설정
# SageMaker 처리 작업을 시작하기 전에 [`FrameworkProcessor`](https://docs.aws.amazon.com/sagemaker/latest/dg/processing-job-frameworks.html) 객체를 인스턴스화합니다. 로컬 모드를 활성화하기 위해 인스턴스 타입을 `local`로 설정하고 `sagemaker_session` 파라미터로 `LocalSession()` 객체를 제공합니다.
#
# SageMaker가 처리 컨테이너의 EBS 볼륨의 로컬 경로에 데이터를 매핑하는 방식:
#
# ![](img/data-processing.png)
#
# 입력 데이터는 로컬 디렉토리, S3 버킷, Amazon Athena, Amazon Redshift에서 다운로드할 수 있습니다. 로컬 처리 작업의 경우 이 로컬 JupyterLab 스페이스에서 입력 데이터를 다운로드하고 출력 데이터를 S3 버킷에 업로드합니다.
#
# 먼저 데이터셋의 S3 출력 위치를 정의합니다.

# %%
train_s3_url = s3_path_join("s3://", bucket_name, bucket_prefix, "train")
validation_s3_url = s3_path_join("s3://", bucket_name, bucket_prefix, "validation")
test_s3_url = s3_path_join("s3://", bucket_name, bucket_prefix, "test")
baseline_s3_url = s3_path_join("s3://", bucket_name, bucket_prefix, "baseline")

# %store train_s3_url
# %store validation_s3_url
# %store test_s3_url
# %store baseline_s3_url

# %% [markdown]
# 다음으로, SageMaker가 처리 작업의 입력 데이터를 찾고 출력 데이터를 저장할 위치를 이해할 수 있도록 `ProcessingInput`과 `ProcessingOutput` 객체를 정의합니다.

# %%
# Get absolute paths
dataset_file_local_path = os.path.abspath(dataset_file_local_path)
local_processing_dir = os.path.abspath("processing")

local_processing_inputs = [
    ProcessingInput(
        input_name="data",
        s3_input=ProcessingS3Input(
            s3_uri=dataset_file_local_path,
            local_path="/opt/ml/processing/input",
            s3_data_type="S3Prefix")
    )
]

# %%
processing_outputs = [
    ProcessingOutput(
        output_name="train",
        s3_output=ProcessingS3Output(
            s3_uri=train_s3_url,
            local_path="/opt/ml/processing/output/train",
            s3_upload_mode="EndOfJob")
    ),
    ProcessingOutput(
        output_name="validation",
        s3_output=ProcessingS3Output(
            s3_uri=validation_s3_url,
            local_path="/opt/ml/processing/output/validation",
            s3_upload_mode="EndOfJob")
    ),
    ProcessingOutput(
        output_name="test",
        s3_output=ProcessingS3Output(
            s3_uri=test_s3_url,
            local_path="/opt/ml/processing/output/test",
            s3_upload_mode="EndOfJob")
    ),
    ProcessingOutput(
        output_name="baseline",
        s3_output=ProcessingS3Output(
            s3_uri=baseline_s3_url,
            local_path="/opt/ml/processing/output/baseline",
            s3_upload_mode="EndOfJob")
    )
]

# %% [markdown]
# 마지막으로, scikit-learn용 사전 빌드된 컨테이너를 가져와 로컬 세션으로 `FrameworkProcessor`를 생성합니다.

# %%
region = Session().boto_region_name
local_session = LocalSession()

processor_image_uri = retrieve(
    framework="sklearn", 
    version="1.4-2",
    region=region
)

processor = FrameworkProcessor(
    image_uri=processor_image_uri,
    role=sm_role,
    instance_type="local",
    instance_count=1,
    sagemaker_session=local_session,
    base_job_name='from-idea-to-prod-processing',
    command=["python3"],
    env={
        'MLFLOW_TRACKING_ARN': mlflow_arn,
        'MLFLOW_EXPERIMENT_NAME': experiment_name,
        'MLFLOW_RUN_ID': run_id,
        'REGION': region,
        'USER': user_profile_name,
    }
)

# %% [markdown]
# <div class="alert alert-info">아래 코드에서 <code>No such file or directory: 'docker'</code> 오류가 발생하면 노트북 00의 <b>Studio 로컬 모드를 위한 Docker 설치</b> 섹션을 실행해야 합니다.</div>

# %% [markdown]
# #### SageMaker 처리 작업 시작

# %% [markdown]
# 프로세서가 처음 실행될 때 ECR에 docker 인증을 하고 기본 SageMaker sklearn 이미지를 가져옵니다. 이후 프로세서 실행은 더 빠릅니다.

# %%
processor.run(
    code="preprocessing.py",
    source_dir="./processing",
    requirements="requirements.txt",
    inputs=local_processing_inputs,
    outputs=processing_outputs,
    wait=False
)

# %%
mlflow.end_run()

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %%
# check that the processing script uploaded the dataset to the S3 prefix
# !aws s3 ls {train_s3_url}/

# %% [markdown]
# ### SageMaker 프레임워크 컨테이너에서 처리 스크립트 원격 실행
# 처리 스크립트를 로컬에서 테스트한 후, 원격 처리 작업으로 쉽게 이동할 수 있습니다. 원격 작업은 더 확장 가능하고, 처리 스크립트가 완료되면 자동으로 종료되며, 파이프라인에 통합될 수 있습니다. 로컬 디렉토리에서 입력 데이터를 읽는 원격 처리 작업을 이 노트북에서 실행할 수 있지만, 원격 처리 작업은 일반적으로 S3에 저장된 입력 데이터와 함께 사용됩니다. 따라서 먼저 `ProcessingInput` 객체를 재정의합니다.

# %%
processing_inputs = [
    ProcessingInput(
        input_name="data",
        s3_input=ProcessingS3Input(
            s3_uri=s3_data_uri,
            local_path="/opt/ml/processing/input",
            s3_data_type="S3Prefix",
            s3_input_mode="File")
    )
]

# %% [markdown]
# 다음으로, 로컬 세션 없이 특정 인스턴스 타입(`ml.r5.xlarge`)으로 `FrameworkProcessor`를 재정의합니다. 나머지는 동일합니다.

# %%
region = Session().boto_region_name

processor_image_uri = retrieve(
    framework="sklearn", 
    version="1.4-2",
    region=region
)

processor = FrameworkProcessor(
    image_uri=processor_image_uri,
    role=sm_role,
    instance_type="ml.m5.xlarge",
    instance_count=1,
    base_job_name='from-idea-to-prod-processing',
    command=["python3"],
    env={
        'MLFLOW_TRACKING_ARN': mlflow_arn,
        'MLFLOW_EXPERIMENT_NAME': experiment_name,
        'MLFLOW_RUN_ID': run_id,
        'REGION': region,
        'USER': user_profile_name,
    }
)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert open medium"/>

# %%
processor.run(
    code="preprocessing.py",
    source_dir="./processing",
    requirements="requirements.txt",
    inputs=processing_inputs,
    outputs=processing_outputs,
    wait=True
)
mlflow.end_run()

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %% [markdown]
# 작업이 완료되면 출력을 가져올 수 있습니다.

# %%
job = processor.latest_job
output_uris = {
    output.output_name: output.s3_output.s3_uri
    for output in job.processing_output_config.outputs
}

def load_output(name):
    return pd.read_csv(StringIO(S3Downloader.read_file(S3Downloader.list(output_uris[name])[0])))

train_data = load_output("train")
validation_data = load_output("validation")
test_data = load_output("test")
baseline_data = load_output("baseline")

# %% [markdown]
# 빠른 정상성 확인을 위해 훈련 데이터의 처음 몇 행을 표시합니다.

# %%
# check the processed data
train_data.head()

# %% [markdown]
# ## SageMaker 훈련 작업으로 모델 훈련
# 처리와 동일한 방식으로 이제 모델 훈련을 [SageMaker 훈련 작업](https://docs.aws.amazon.com/sagemaker/latest/dg/train-model.html)으로 실행할 수 있습니다. 훈련 이미지, 소스 코드, 컴퓨팅 설정을 제공합니다.
#
# 다음 그림은 SageMaker 훈련 옵션을 요약합니다:
#
# ![](img/sagemaker-training-options.png)

# %% [markdown]
# 먼저 훈련 스크립트를 위한 폴더를 생성하고 MLflow가 포함된 requirements.txt를 만듭니다.

# %%
local_training_dir = "./training/"
os.makedirs(local_training_dir, exist_ok=True)
with open(os.path.join(local_training_dir, "requirements.txt"), "w") as file_handle:
    file_handle.write("sagemaker==3.7.1")

# %% [markdown]
# ### 데이터 및 하이퍼파라미터 준비
# 훈련 작업의 데이터 입력 채널을 정의합니다.

# %%
training_input_data = [
    InputData(channel_name='train', data_source=train_s3_url),
    InputData(channel_name='validation', data_source=validation_s3_url),
]

output_s3_url = f"s3://{bucket_name}/{bucket_prefix}/output"
# %store output_s3_url

# %% [markdown]
# 훈련 작업의 인스턴스 타입과 인스턴스 수를 설정합니다.

# %%
train_instance_count = 1
train_instance_type = "ml.r5.xlarge"

# %% [markdown]
# 하이퍼파라미터와 MLflow 설정을 환경 변수로 준비합니다.

# %%
hyperparams = {
    'num_round': 50,
    'max_depth': 3,
    'eta': 0.5,
    'alpha': 2.5,
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'min_child_weight': 3,
    'early_stopping_rounds': 10,
    'verbosity': 1
}

# %%
env_variables = {
    'MLFLOW_TRACKING_ARN': mlflow_arn,
    'MLFLOW_EXPERIMENT_NAME': experiment_name,
    'USER': user_profile_name,
    'REGION': region,
}

print(env_variables)

# %% [markdown]
# ### `@remote` 데코레이터로 훈련
# 먼저 [`@remote` 데코레이터](https://docs.aws.amazon.com/sagemaker/latest/dg/train-remote-decorator-invocation.html)를 사용하는 방법을 보여줍니다. 이 데코레이터를 사용하면 Python 함수를 원격 SageMaker 훈련 작업으로 실행할 수 있습니다. 로컬 훈련 코드를 SageMaker 관리 인프라로 이동하는 가장 간단한 방법입니다.

# %% [markdown]
# #### `train_xgboost` 로컬 함수 정의

# %%
## set ENV variables locally
for k, v in env_variables.items():
    os.environ[k] = v

# %%
def train_xgboost(train_uri, validation_uri, hyperparams):
    """Train an XGBoost model"""
    import os
    import boto3
    import pandas as pd
    import xgboost as xgb
    from sklearn.metrics import roc_auc_score
    import mlflow
    from io import StringIO

    # Download data from S3
    s3 = boto3.client('s3')
    print(os.environ)
    def read_csv_from_s3(s3_uri):
        bucket = s3_uri.split('/')[2]
        key = '/'.join(s3_uri.split('/')[3:])
        # List objects to find CSV files
        resp = s3.list_objects_v2(Bucket=bucket, Prefix=key)
        csv_files = [o['Key'] for o in resp.get('Contents', []) if o['Key'].endswith('.csv')]
        dfs = []
        for f in csv_files:
            obj = s3.get_object(Bucket=bucket, Key=f)
            dfs.append(pd.read_csv(StringIO(obj['Body'].read().decode('utf-8')), header=None))
        return pd.concat(dfs, ignore_index=True)

    train_df = read_csv_from_s3(train_uri)
    val_df = read_csv_from_s3(validation_uri)

    dtrain = xgb.DMatrix(train_df.iloc[:, 1:], label=train_df.iloc[:, 0])
    dval = xgb.DMatrix(val_df.iloc[:, 1:], label=val_df.iloc[:, 0])

    # Setup MLflow
    mlflow.set_tracking_uri(os.getenv('MLFLOW_TRACKING_ARN'))
    mlflow.set_experiment(experiment_name=os.getenv('MLFLOW_EXPERIMENT_NAME'))
    mlflow.xgboost.autolog(log_model_signatures=True, log_datasets=True)

    train_hp = {k: v for k, v in hyperparams.items() if k not in ('num_round', 'eval_metric', 'early_stopping_rounds', 'alpha', 'colsample_bytree')}

    with mlflow.start_run(run_name='remote-decorator-training', description='xgboost via @remote decorator') as run:
        booster = xgb.train(
            params=train_hp,
            dtrain=dtrain,
            evals=[(dtrain, 'train'), (dval, 'validation')],
            num_boost_round=hyperparams['num_round'],
        )
        val_auc = roc_auc_score(dval.get_label(), booster.predict(dval))
        train_auc = roc_auc_score(dtrain.get_label(), booster.predict(dtrain))
        mlflow.log_metrics({'validation_auc': val_auc, 'train_auc': train_auc})
        print(f'train-auc: {train_auc:.4f}, validation-auc: {val_auc:.4f}')

    return booster

# %% [markdown]
# #### 함수를 로컬에서 테스트

# %%
booster = train_xgboost(train_s3_url, validation_s3_url, hyperparams)

# %% [markdown]
# #### `@remote` 데코레이터로 함수에 어노테이션 달기
# 로컬 테스트가 성공하면 함수를 SageMaker 관리 인프라에서 실행하도록 이동할 수 있습니다. 함수에 어노테이션을 달아 이를 수행합니다. 함수를 재정의하지 않기 위해 동일한 시그니처를 가진 래퍼 함수 `remote_train_xgboost`에 어노테이션을 달고 원래 함수 `train_xgboost`를 호출합니다.

# %%
# %store -r xgboost_image
xgboost_image

# %%
@remote(
    instance_type=train_instance_type,
    role=sm_role,
    dependencies='./training/requirements.txt',
    environment_variables=env_variables,
    job_name_prefix='from-idea-to-prod-remote',
    keep_alive_period_in_seconds=3600,
    image_uri=xgboost_image
)
def remote_train_xgboost(train_uri, validation_uri, hyperparams):
    """Train an XGBoost model using the @remote decorator."""
    return train_xgboost(train_uri, validation_uri, hyperparams)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert open medium"/>

# %%
booster = remote_train_xgboost(train_s3_url, validation_s3_url, hyperparams)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %% [markdown]
# ---
#
# `@remote` 데코레이터는 로컬 코드를 SageMaker로 이동하는 가장 빠른 방법입니다. 다음으로, 훈련 컨테이너, 스크립트 패키징, 출력 아티팩트에 대한 더 많은 제어를 제공하는 `ModelTrainer`를 사용합니다 — SageMaker Pipelines에서 사용되는 것과 동일한 패턴입니다.

# %% [markdown]
# ### `ModelTrainer`를 스크립트 모드로 훈련
# [`ModelTrainer`](https://sagemaker.readthedocs.io/en/stable/api/training/model_trainer.html) 클래스는 훈련 작업 설정에 대한 완전한 제어를 제공합니다. 커스텀 하이퍼파라미터, 입력 채널, 출력 위치로 SageMaker 내장 알고리즘 컨테이너 내에서 훈련 스크립트를 실행해야 할 때 사용합니다.

# %% [markdown]
# 이전 섹션에서 `@remote` 데코레이터를 사용했을 때 SageMaker는 노트북 환경과 추가 requirements.txt를 기반으로 훈련 작업을 실행했습니다. [ModelTrainer](https://sagemaker.readthedocs.io/en/stable/training/index.html)로 원격 훈련 작업을 실행하기 위해 Docker 이미지를 환경으로 지정합니다. SageMaker에서 커스텀 컨테이너를 가져올 수 있지만, [사전 빌드된 XGBoost 컨테이너](https://github.com/aws/sagemaker-xgboost-container)를 가져옵니다.

# %%
xgb_training_image = xgboost_image
print(f'XGBoost training image: {xgb_training_image}')

# %% [markdown]
# #### 훈련 스크립트 준비
# 훈련 스크립트가 포함된 `train.py` 파일을 생성합니다.

# %%
# %%writefile ./training/train.py
import argparse
import json
import os
import pickle as pkl

import pandas as pd
from sklearn.metrics import roc_auc_score
from sagemaker_xgboost_container.data_utils import get_dmatrix
import xgboost as xgb

from time import gmtime, strftime

suffix = strftime('%d-%H-%M-%S', gmtime())
user_profile_name = os.getenv('USER', 'sagemaker')
experiment_name = os.getenv('MLFLOW_EXPERIMENT_NAME')
region = os.getenv('REGION')


def _xgb_train(params, dtrain, dval, evals, num_boost_round, model_dir, is_master):
    booster = xgb.train(params=params, dtrain=dtrain, evals=evals, num_boost_round=num_boost_round)

    val_auc = roc_auc_score(dval.get_label(), booster.predict(dval))
    train_auc = roc_auc_score(dtrain.get_label(), booster.predict(dtrain))
    mlflow.log_params(params)
    mlflow.log_metrics({'validation_auc': val_auc, 'train_auc': train_auc})
    print(f'[0]#011train-auc:{train_auc}#011validation-auc:{val_auc}')

    if is_master:
        model_location = model_dir + '/xgboost-model'
        pkl.dump(booster, open(model_location, 'wb'))
        print(f'Stored trained model at {model_location}')


if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--max_depth', type=int)
    parser.add_argument('--eta', type=float)
    parser.add_argument('--alpha', type=float)
    parser.add_argument('--gamma', type=int)
    parser.add_argument('--min_child_weight', type=float)
    parser.add_argument('--subsample', type=float)
    parser.add_argument('--colsample_bytree', type=float)
    parser.add_argument('--verbosity', type=int)
    parser.add_argument('--objective', type=str)
    parser.add_argument('--num_round', type=int)
    parser.add_argument('--early_stopping_rounds', type=int)
    parser.add_argument('--tree_method', type=str, default='auto')
    parser.add_argument('--predictor', type=str, default='auto')
    parser.add_argument('--output_data_dir', type=str, default=os.environ.get('SM_OUTPUT_DATA_DIR'))
    parser.add_argument('--model_dir', type=str, default=os.environ.get('SM_MODEL_DIR'))
    parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAIN'))
    parser.add_argument('--validation', type=str, default=os.environ.get('SM_CHANNEL_VALIDATION'))
    parser.add_argument('--sm_hosts', type=str, default=os.environ.get('SM_HOSTS'))
    parser.add_argument('--sm_current_host', type=str, default=os.environ.get('SM_CURRENT_HOST'))
    parser.add_argument('--sm_training_env', type=str, default=os.environ.get('SM_TRAINING_ENV'))

    args, _ = parser.parse_known_args()

    sm_hosts = json.loads(args.sm_hosts)
    sm_current_host = args.sm_current_host
    dtrain = get_dmatrix(args.train, 'CSV')
    dval = get_dmatrix(args.validation, 'CSV')
    watchlist = [(dtrain, 'train'), (dval, 'validation')] if dval is not None else [(dtrain, 'train')]
    sm_training_env = json.loads(args.sm_training_env)

    import mlflow
    mlflow.set_tracking_uri(os.getenv('MLFLOW_TRACKING_ARN'))
    mlflow.set_experiment(experiment_name=experiment_name if experiment_name else f'train-{suffix}')
    mlflow.xgboost.autolog(log_model_signatures=True, log_datasets=True)

    train_hp = {
        'max_depth': args.max_depth, 'eta': args.eta, 'gamma': args.gamma,
        'min_child_weight': args.min_child_weight, 'subsample': args.subsample,
        'verbosity': args.verbosity, 'objective': args.objective,
        'tree_method': args.tree_method, 'predictor': args.predictor,
    }

    xgb_train_args = dict(
        params=train_hp, dtrain=dtrain, dval=dval, evals=watchlist,
        num_boost_round=args.num_round, model_dir=args.model_dir,
    )

    # Resume parent run if MLFLOW_RUN_ID is set (for nested run grouping)
    parent_run_id = os.getenv('MLFLOW_RUN_ID')
    if parent_run_id:
        mlflow.start_run(run_id=parent_run_id)

    with mlflow.start_run(
        run_name=f'container-training-{suffix}',
        description='xgboost running in SageMaker container in script mode',
        nested=True if parent_run_id else False,
    ) as run:
        mlflow.set_tags({
            'mlflow.user': user_profile_name,
            'mlflow.source.type': 'JOB',
            'mlflow.source.name': f"https://{region}.console.aws.amazon.com/sagemaker/home?region={region}#/jobs/{sm_training_env['job_name']}",
            'sagemaker.container_image': sm_training_env.get('additional_framework_parameters', {}).get('sagemaker_training_image', os.environ.get('TRAINING_JOB_ARN', 'n/a')),
            'sagemaker.job_name': sm_training_env['job_name'],
            'sagemaker.runtime': 'sagemaker',
        })
        if dtrain:
            xgb_train_args['is_master'] = True
            _xgb_train(**xgb_train_args)
        else:
            raise ValueError('Training channel must have data to train model.')

        # Write MLflow run_id to model dir so it gets packaged in model.tar.gz
        with open(os.path.join(args.model_dir, 'mlflow_run_id.txt'), 'w') as f:
            f.write(run.info.run_id)

# %% [markdown]
# 이제 올바른 Docker 이미지, 소스 코드, 컴퓨팅 사양, 하이퍼파라미터, 환경 변수로 `ModelTrainer`를 정의합니다. 앞서 적용한 동일한 로직에 따라 관리 인프라에서 작업을 시작하기 전에 스크립트에 버그가 없는지 로컬에서 테스트합니다.
#
# `ModelTrainer`는 두 가지 `training_modes`를 제공합니다: `LOCAL_CONTAINER`와 `SAGEMAKER_TRAINING_JOB`. `LOCAL_CONTAINER`부터 시작합니다.

# %%
from sagemaker.train.model_trainer import Mode

# %%
train_locally = ModelTrainer(
    training_image=xgb_training_image,
    source_code=SourceCode(
        source_dir="./training",
        ## the xgboost 3.0-5 has a bug that will be solved with the pip3 install -r requirements.txt see: https://github.com/aws/sagemaker-xgboost-container/pull/465
        entry_script="train.py",
        # requirements="requirements.txt",  # relative to source_dir
        # command=f"/miniconda3/bin/python3 -m pip install -r /opt/ml/input/data/code/requirements.txt && /miniconda3/bin/python3 /opt/ml/input/data/code/train.py {' '.join(f'--{k} {v}' for k, v in hyperparams.items())}",
    ),
    compute=Compute(instance_type="local", instance_count=1),
    training_mode=Mode.LOCAL_CONTAINER,
    hyperparameters=hyperparams,
    base_job_name='from-idea-to-prod-local',
    environment=env_variables,
)

# %% [markdown]
# <div class="alert alert-info">아래 코드에서 <code>No such file or directory: 'docker'</code> 오류가 발생하면 노트북 00의 <b>Studio 로컬 모드를 위한 Docker 설치</b> 섹션을 실행해야 합니다.</div>

# %%
train_locally.train(
    input_data_config=[
        InputData(channel_name="train", data_source=train_s3_url, content_type="text/csv"),
        InputData(channel_name="validation", data_source=validation_s3_url, content_type="text/csv"),
    ],
    wait=True,
    logs=True,
)

# %% [markdown]
# 이제 SageMaker 관리 인프라에서 훈련을 진행할 준비가 되었습니다.

# %%
trainer_managed = ModelTrainer(
    training_image=xgb_training_image,
    source_code=SourceCode(
        source_dir="./training",
        ## the xgboost 3.0-5 has a bug that will be solved with the pip3 install -r requirements.txt see: https://github.com/aws/sagemaker-xgboost-container/pull/465
        entry_script="train.py",
        # requirements="requirements.txt",  # relative to source_dir
        # command=f"/miniconda3/bin/python3 -m pip install -r /opt/ml/input/data/code/requirements.txt && /miniconda3/bin/python3 /opt/ml/input/data/code/train.py {' '.join(f'--{k} {v}' for k, v in hyperparams.items())}",
    ),
    compute=Compute(
        instance_type=train_instance_type,
        instance_count=train_instance_count
    ),
    hyperparameters=hyperparams,
    base_job_name='from-idea-to-prod-training',
    training_mode=Mode.SAGEMAKER_TRAINING_JOB,
    output_data_config=OutputDataConfig(s3_output_path=output_s3_url),
    environment=env_variables,
)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert open medium"/>

# %%
trainer_managed.train(
    input_data_config=training_input_data,
    wait=True,
    logs=False,
)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %% [markdown]
# 훈련 작업이 완료되면 출력 아티팩트를 가져올 수 있습니다.

# %%
training_job = trainer_managed._latest_training_job
print(f"Training job: {training_job.training_job_name}")
print(f"Model artifacts: {training_job.model_artifacts.s3_model_artifacts}")

# %%
display(
    HTML('<b>See the SageMaker <a target="top" href="https://{}.console.aws.amazon.com/sagemaker/home?region={}#/jobs/{}">training job</a></b>'.format(
            region, region, trainer_managed._latest_training_job.training_job_name))
)

# %% [markdown]
# #### MLflow 모델 레지스트리에 모델 등록
# 이제 훈련된 모델을 MLflow 모델 레지스트리에 등록합니다. MLflow 앱이 `AutoModelRegistrationEnabled`로 생성되었으므로(노트북 00 참조), 이는 [SageMaker 모델 레지스트리](https://docs.aws.amazon.com/sagemaker/latest/dg/model-registry.html)에 해당 모델 패키지도 자동으로 생성합니다. 두 곳에 별도로 등록할 필요가 없습니다.

# %%
registered_model_name = name_from_base("from-idea-to-prod-job-model-", short=True)

# %% [markdown]
# MLflow에서 최신 실행을 가져와 이 실행에서 모델을 등록합니다.

# %%
last_run_id = mlflow.search_runs(
    experiment_ids=[mlflow.get_experiment_by_name(experiment_name).experiment_id], 
    max_results=1, 
    order_by=["attributes.start_time DESC"]
)['run_id'][0]

model_uri = f"runs:/{last_run_id}/model"
registered_model_version = mlflow.register_model(model_uri, registered_model_name)

# %% [markdown]
# 등록된 모델의 메트릭과 메타데이터를 출력합니다.

# %%
print(f"Model: {registered_model_version.name}, version: {registered_model_version.version}")
print(f"Tags: {registered_model_version.tags}")
print(f"Aliases: {registered_model_version.aliases}")
print(f"\nMetrics:")
mlflow.get_run(registered_model_version.run_id).data.metrics

# %% [markdown]
# ## 모델 배포 및 테스트
# 모든 훈련 작업은 Amazon S3의 지정된 출력 위치에 모델 패키지를 저장합니다.
#
# 먼저 노트북에서 로컬로 모델을 추론에 성공적으로 사용할 수 있는지 테스트합니다. 그런 다음 `ModelBuilder`를 사용하여 모델을 [실시간 엔드포인트](https://docs.aws.amazon.com/sagemaker/latest/dg/realtime-endpoints.html)로 배포합니다.

# %% [markdown]
# ### 테스트 데이터 준비
# S3에서 노트북으로 준비된 테스트 데이터셋을 다운로드합니다.

# %%
# !aws s3 cp $test_s3_url/test_x.csv tmp/test_x.csv
# !aws s3 cp $test_s3_url/test_y.csv tmp/test_y.csv

# %% [markdown]
# ### 노트북에서 로컬 추론
# 먼저 MLflow 모델 레지스트리에서 등록된 모델을 사용하여 로컬로 추론을 실행합니다.

# %%
model_uri = registered_model_version.source
model = mlflow.xgboost.load_model(model_uri)

# %%
test_x = np.loadtxt("tmp/test_x.csv", delimiter=",")
test_y = np.loadtxt("tmp/test_y.csv", delimiter=",")

dtest = xgb.DMatrix(test_x)
predictions = np.array(model.predict(dtest), dtype=float).squeeze()
predictions

# %%
pd.crosstab(
    index=test_y,
    columns=np.round(predictions), 
    rownames=['actuals'], 
    colnames=['predictions']
)

# %% [markdown]
# ### MLflow 모델 레지스트리를 사용한 ModelBuilder로 배포
#
# `InferenceSpec`과 함께 `ModelBuilder`를 사용하여 MLflow에 등록된 모델을 배포합니다. `InferenceSpec`은 MLflow에서 모델을 로드하고 추론을 실행하는 방법을 정의합니다. 먼저 `IN_PROCESS` 모드(Docker나 엔드포인트 불필요)로 테스트한 후 실제 SageMaker 엔드포인트에 배포합니다.

# %%
from sagemaker.serve import ModelBuilder
from sagemaker.serve.mode.function_pointers import Mode
from sagemaker.serve.spec.inference_spec import InferenceSpec
from sagemaker.serve.builder.schema_builder import SchemaBuilder

class XGBoostMLflowSpec(InferenceSpec):
    def __init__(self, mlflow_model_uri, tracking_uri):
        self._mlflow_model_uri = mlflow_model_uri
        self._tracking_uri = tracking_uri

    def load(self, model_dir=None):
        import mlflow
        mlflow.set_tracking_uri(self._tracking_uri)
        return mlflow.xgboost.load_model(self._mlflow_model_uri)

    def invoke(self, input_object, model):
        import xgboost as xgb
        import numpy as np
        if isinstance(input_object, str):
            rows = [list(map(float, r.split(","))) for r in input_object.strip().split("\n") if r]
            dmatrix = xgb.DMatrix(np.array(rows))
        elif isinstance(input_object, list):
            dmatrix = xgb.DMatrix(np.array(input_object))
        else:
            dmatrix = xgb.DMatrix(np.array(input_object))
        return "\n".join(map(str, model.predict(dmatrix)))

# Use models:/name/version format
mlflow_model_path = f"models:/{registered_model_version.name}/{registered_model_version.version}"

schema_builder = SchemaBuilder(
    sample_input=",".join(map(str, test_x[0])),
    sample_output="0.5",
)

# %% [markdown]
# #### IN_PROCESS 모드로 테스트
# `IN_PROCESS` 모드는 노트북 프로세스에서 직접 모델을 실행합니다 — Docker나 엔드포인트가 필요 없습니다. 추론 로직을 검증하는 가장 빠른 방법입니다.

# %%
from sagemaker.serve.utils.types import ModelServer

model_builder = ModelBuilder(
    inference_spec=XGBoostMLflowSpec(mlflow_model_path, mlflow_arn),
    schema_builder=schema_builder,
    mode=Mode.IN_PROCESS,
    model_server=ModelServer.TORCHSERVE,
)
model_builder.secret_key = ""
model_builder.build()

endpoint_in_process = model_builder.deploy(endpoint_name="in-process-xgb")

# %%
import json as json_mod

csv_payload = '\n'.join([','.join(map(str, row)) for row in test_x])
response = endpoint_in_process.invoke(csv_payload, content_type='text/csv')

body = response.body if hasattr(response, 'body') else response
if hasattr(body, 'read'): body = body.read()
if isinstance(body, bytes): body = body.decode('utf-8')
try:
    body = json_mod.loads(body)
except: pass
predictions = np.array(body.strip().split('\n'), dtype=float).squeeze()

test_auc = roc_auc_score(test_y, predictions)
print(f'Test-auc (IN_PROCESS): {test_auc:.4f}')

# %%
endpoint_in_process.delete()

# %% [markdown]
# #### 실시간 SageMaker 엔드포인트에 배포
#
# 이제 `SAGEMAKER_ENDPOINT` 모드로 `ModelBuilder`를 사용하여 모델을 배포합니다. SageMaker XGBoost 컨테이너는 추론 코드가 모델 아티팩트의 `code/` 디렉토리에 패키징되어 있어야 합니다. `ModelTrainer`는 추론 코드를 자동으로 패키징하지 않으므로, 배포 전에 SDK의 `repack_model` 유틸리티를 사용하여 커스텀 `inference.py`를 모델 tarball에 추가합니다.

# %%
endpoint_model_builder = ModelBuilder(
    # s3_model_data_url=repacked_s3_uri,
    image_uri=xgb_training_image,
    instance_type='ml.r5.xlarge',
    inference_spec=XGBoostMLflowSpec(mlflow_model_path, mlflow_arn),
    schema_builder=schema_builder,
    model_server=ModelServer.TORCHSERVE,
    dependencies={
        "auto": False,
        # "custom": [
        #     "setuptools==81.0.0",
        #     "sagemaker-mlflow>=0.2.0",
        #     "sagemaker==3.7.0",
        #     "cloudpickle==3.1.2",
        #     "protobuf>=3.20.0,<3.21",
        #     "Flask>=2.0,<3.0",
        #     "Jinja2>=3.0,<3.2",
        # ]
    }
)
endpoint_model_builder.build()

# %%
endpoint_name = name_from_base("from-idea-to-prod-job-endpoint-", short=True)
endpoint = endpoint_model_builder.deploy(
    endpoint_name=endpoint_name,
    initial_instance_count=1,
    instance_type='ml.r5.xlarge',
)

# %%
display(
    HTML('<b>See the SageMaker <a target="top" href="https://{}.console.aws.amazon.com/sagemaker/home?region={}#/endpoints/{}">inference endpoint</a></b>'.format(
            region, region, endpoint_name))
)

# %% [markdown]
# #### 엔드포인트 예측 테스트
#
# 엔드포인트가 실행되면 샘플 페이로드로 호출하여 작동하는지 확인합니다.

# %%
sm_runtime = boto3.client('sagemaker-runtime')

csv_data = '\n'.join([','.join(map(str, row)) for row in test_x])

response = sm_runtime.invoke_endpoint(
    EndpointName=endpoint_name,
    ContentType='text/csv',
    Accept='text/csv',
    Body=csv_data,
)
predictions = np.array(response['Body'].read().decode('utf-8').strip().split('\n'), dtype=float).squeeze()
predictions

# %%
pd.crosstab(
    index=test_y,
    columns=np.round(predictions), 
    rownames=['actuals'], 
    colnames=['predictions']
)

# %%
test_auc = roc_auc_score(test_y, predictions)
print(f"Test-auc: {test_auc:.4f}")

# %% [markdown]
# #### MLflow 실행에 차트 저장
#
# 테스트 데이터의 혼동 행렬을 참조용으로 MLflow에 저장하는 것이 좋습니다.

# %%
def plot_confusion_matrix(
    cm, class_names, title="Confusion matrix", cmap=plt.cm.Blues, normalize=False
):
    if normalize:
        cm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation="nearest", cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(
        xticks=np.arange(cm.shape[1]),
        yticks=np.arange(cm.shape[0]),
        ylim=(cm.shape[0] - 0.5, -0.5),
        xticklabels=class_names,
        yticklabels=class_names,
        title=title,
        ylabel="Ground truth label",
        xlabel="Predicted label",
    )
    plt.setp(ax.get_xticklabels(), rotation=30, ha="right", rotation_mode="anchor")
    fmt = ".2f"
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt), ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax, fig

# %%
class_names = ["no", "yes"]
confusion_matrix = metrics.confusion_matrix(test_y, np.round(predictions))
ax, fig = plot_confusion_matrix(confusion_matrix, class_names)

# %%
print(f"Log confusion matrix to the model {registered_model_version.name} version {registered_model_version.version}")
mlflow.set_experiment(experiment_name)
with mlflow.start_run(run_id=registered_model_version.run_id):
    mlflow.log_figure(fig, "confusion_matrix.png")

# %% [markdown]
# ## MLflow UI로 실험 및 모델 레지스트리 탐색
# Studio UI의 **애플리케이션** 패널에서 **MLflow**를 선택하고, MLflow 서버를 선택한 후 **Open MLflow**를 클릭하여 MLflow UI를 실행합니다:
#
# ![](img/mlflow-open.png)
#
# MLflow UI에서 실험, 실행, 등록된 모델을 탐색할 수 있습니다:
#
# ![](img/experiment-mlflow-2.png)
#
# ![](img/models-mlflow-2.png)
#
# ![](img/model-fig-mlflow.png)

# %% [markdown]
# ## 정리
# 불필요한 비용을 방지하기 위해 생성한 배포된 엔드포인트를 제거합니다.

# %%
sm_client = boto3.client('sagemaker')
endpoints = sm_client.list_endpoints()["Endpoints"]

for ep in endpoints:
    ep_name = ep['EndpointName']
    if 'from-idea-to-prod' in ep_name:
        try:
            print(f"Deleting endpoint: {ep_name}")
            sm_client.delete_endpoint(EndpointName=ep_name)
        except Exception as e:
            print(f"Error deleting {ep_name}: {e}")

print("Cleanup complete.")

# %% [markdown]
# ## 요약
#
# 이 노트북에서 로컬 노트북 코드에서 SageMaker 관리 인프라로 이동했습니다:
#
# - **처리**: `FrameworkProcessor`를 사용하여 동일한 전처리 스크립트를 로컬과 원격으로 실행
# - **`@remote`로 훈련**: 단일 데코레이터로 로컬 Python 함수를 SageMaker 훈련 작업으로 전환
# - **`ModelTrainer`로 훈련**: 훈련 컨테이너와 아티팩트에 대한 완전한 제어를 위해 스크립트 모드 사용
# - **배포**: `IN_PROCESS` 모드로 로컬에서 추론을 테스트한 후 `ModelBuilder`를 사용하여 실시간 SageMaker 엔드포인트에 배포
#
# 다음 노트북에서는 이러한 처리 및 훈련 단계를 SageMaker Pipelines를 사용하여 **자동화된 ML 파이프라인**으로 결합합니다.

# %% [markdown]
# ## 실제 프로젝트를 위한 추가 개발 아이디어
# - [MLflow로 실험 관리](https://docs.aws.amazon.com/sagemaker/latest/dg/mlflow.html)에 대해 더 알아보세요
# - 데이터에 대해 코드 없는 [SageMaker Canvas](https://docs.aws.amazon.com/sagemaker/latest/dg/canvas.html)를 사용하여 분석을 수행하고 자동화된 ML로 모델을 빌드하세요
# - 모델 훈련을 개선하려면 [자동화된 하이퍼파라미터 튜닝](https://docs.aws.amazon.com/sagemaker/latest/dg/automatic-model-tuning.html)을 시도해 보세요

# %% [markdown]
# ## 추가 리소스
# - [SageMaker에서 Docker 컨테이너 사용](https://docs.aws.amazon.com/sagemaker/latest/dg/docker-containers.html)
# - [Amazon SageMaker 이머전 데이](https://catalog.us-east-1.prod.workshops.aws/workshops/63069e26-921c-4ce1-9cc7-dd882ff62575/en-US)
# - [Amazon SageMaker 예제 GitHub 저장소](https://github.com/aws/amazon-sagemaker-examples)
# - [Amazon SageMaker 커뮤니티 예제 GitHub 저장소](https://github.com/aws/amazon-sagemaker-examples-community)

# %% [markdown]
# # 커널 종료

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
