# %% [markdown]
# # 1단계: 노트북에서 실험하기
# <div style="border: 2px solid #ff9900; border-radius: 8px; padding: 15px; background-color: #fff3e0; margin-bottom: 10px;">
# <strong>⚠️ 호환성 안내:</strong> 이 노트북은 <strong>SageMaker Distribution Image 4.0.0</strong> 및 <strong>SageMaker Python SDK 버전 3.7.1</strong>에서 테스트되었습니다.
# </div>
#
# 이 단계에서는 노트북 내에서 로컬로 데이터 처리, 모델 훈련 및 평가를 실행합니다. `sagemaker` 또는 `boto3` 패키지는 사용하지 않습니다. 이 방식은 소규모 데이터 서브셋에서 빠른 프로토타이핑에 적합하지만, 확장에는 권장되지 않습니다.
#
# **아이디어에서 프로덕션까지 6단계:**
# ||||
# |---|---|---|
# |1. |노트북에서 실험하기 |**<<<< 현재 위치**|
# |2. |SageMaker AI 처리 작업과 SageMaker SDK로 확장하기 ||
# |3. |ML 파이프라인, 모델 레지스트리로 운영화하기 ||
# |4. |모델 빌드 CI/CD 파이프라인 추가하기 ||
# |5. |모델 배포 파이프라인 추가하기 ||
# |6. |모델 및 데이터 모니터링 추가하기 ||

# %% [markdown]
# <div style="border: 4px solid #d32f2f; border-radius: 10px; padding: 20px; background-color: #ffebee; margin: 15px 0;">
#
# ### ⛔ 중요: Python 3.10 필수
#
# 이 워크샵의 모든 노트북은 **Python 3.10**에서 실행해야 합니다. 다른 Python 버전을 사용하면 아래 셀이 `AssertionError`로 실패합니다.
#
# 오류가 발생하면 다음 단계를 따르세요:
#
# 1. JupyterLab에서 **터미널**을 엽니다 (**File → New → Terminal**)
# 2. 설정 스크립트를 실행합니다:
#    ```bash
#    cd ~/amazon-sagemaker-from-idea-to-production
#    ./setup-py310.sh
#    ```
# 3. 새 커널을 적용하려면 **브라우저를 새로고침**합니다
# 4. 이 노트북에서 **Kernel → Change Kernel → Python 3.10**으로 이동합니다
# 5. **커널을 재시작**하고 처음부터 다시 실행합니다
#
# </div>

# %% [markdown]
# > 💡 **설명**: **[실습]** SageMaker SDK를 최신 버전으로 설치합니다. 이 워크샵은 SDK v3 기반으로 작성되어 있으므로 반드시 실행하세요.

# %%
# %pip uninstall -y sagemaker sagemaker-core sagemaker-train sagemaker-serve sagemaker-mlops
# %pip install --no-cache-dir sagemaker-core==2.7.1 \
    sagemaker-train==1.7.1 \
    sagemaker-serve==1.7.1 --extra-index-url https://download.pytorch.org/whl/cpu \
    sagemaker-mlops==1.7.1 \
    sagemaker==3.7.1 \
    "mlflow<4" \
    sagemaker-mlflow==0.2.0
# %pip install xgboost==3.0.5 scikit-learn==1.4.2 s3fs aiobotocore boto3 pickleshare ipywidgets

# %% [markdown]
# > 💡 **설명**: **[실습]** Python 버전이 3.10인지 확인합니다. 다른 버전이면 오류가 발생합니다. 오류 시 노트북 상단의 안내를 따라 커널을 변경하세요.

# %%
import sys

assert sys.version_info[:2] == (3, 10), f"Expected Python 3.10, got {sys.version_info.major}.{sys.version_info.minor}. Please make sure you run on Python 3.10"

# %% [markdown]
# ### 설치된 SageMaker 버전 확인

# %% [markdown]
# > 💡 **설명**: **[실습]** 설치된 SageMaker SDK 버전을 출력합니다. `3.7.x` 이상인지 확인하세요.

# %%
import sagemaker
import sagemaker.core
import sagemaker.train
import sagemaker.serve
import sagemaker.mlops
from importlib.metadata import version

print(f"sagemaker: {version('sagemaker')}")
print(f"sagemaker.core: {version('sagemaker.core')}")
print(f"sagemaker.train: {version('sagemaker.train')}")
print(f"sagemaker.server: {version('sagemaker.serve')}")
print(f"sagemaker.mlops: {version('sagemaker.mlops')}")

# %% [markdown]
# ### 패키지 임포트

# %% [markdown]
# > 💡 **설명**: **[실습]** 이 노트북에서 사용할 라이브러리를 임포트합니다. pandas, numpy, xgboost, mlflow 등 순수 ML 라이브러리만 사용합니다. SageMaker SDK는 거의 사용하지 않는 것이 이 노트북의 특징입니다.

# %%
import os
import time
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import mlflow
import mlflow.sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score

from sagemaker.core.resources import MlflowApp
from sagemaker.core.s3.client import S3Downloader
from sagemaker.core.s3.client import s3_path_join
from sagemaker.core.common_utils import name_from_base

# %% [markdown]
# 이전 노트북에서 저장된 변수를 로드합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 노트북 00에서 `%store`로 저장해둔 변수(S3 버킷명, MLflow ARN 등)를 불러옵니다. `initialized` 변수가 없으면 00 노트북을 먼저 실행하라는 안내가 출력됩니다.

# %%
# %store -r 

# %store

try:
    initialized
except NameError:
    print("+++++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN 00-start-here notebook   ")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++")

# %% [markdown]
# 이전에 저장된 변수 외에도, 데이터셋의 타겟 변수 컬럼 이름을 설정하고 저장합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 타겟 컬럼명 `y`를 변수로 저장하고 `%store`로 다음 노트북에서도 사용할 수 있게 합니다.

# %%
target_col = "y"
# %store target_col

# %% [markdown]
# ## 데이터 로드
#
# 데이터셋은 노트북 00에서 이미 로컬에 있습니다. 아래의 파라미터화된 셀은 이 노트북을 [SageMaker 작업](https://docs.aws.amazon.com/sagemaker/latest/dg/notebook-auto-run.html)으로 실행하는 것도 지원합니다 — 자세한 내용은 이 노트북 끝의 선택적 섹션을 참조하세요.

# %% [markdown]
# > 💡 **설명**: **[실습]** 데이터 파일 경로를 설정합니다. `parameters` 태그가 붙은 셀로, 노트북을 SageMaker 헤드리스 작업으로 실행할 때 이 값이 외부에서 주입됩니다. 지금은 로컬 파일을 사용합니다.

# %%
# This cell is tagged with `parameters` tag and will be overwritten if the notebook executed headlessly
file_source = "local"
file_name = "bank-additional-full.csv"
input_path = "./data/bank-additional" 
output_path = "./data"

# %% [markdown]
# 노트북이 작업으로 비대화형 또는 헤드리스 방식으로 실행되는 경우, 노트북은 JupyterLab EBS 볼륨에 접근할 수 없습니다. 따라서 다음 셀은 S3에서 데이터셋을 다운로드합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 헤드리스 실행 시 S3에서 데이터를 다운로드하는 분기 코드입니다. 지금은 `file_source == 'local'`이므로 실행되지 않습니다.

# %%
if file_source != "local":
    S3Downloader.download(
        s3_uri=s3_path_join("s3://", bucket_name, bucket_prefix, "input", file_name),
        local_path=os.path.join(input_path, "")
    )

# %% [markdown]
# ## MLflow 앱 준비 확인

# %% [markdown]
# > 💡 **설명**: **[실습]** MLflow 앱이 준비 상태인지 확인합니다. 앱이 시작 중이면 최대 5분 대기합니다.

# %%
from sagemaker.core.resources import App
from sagemaker.core.resources import MlflowApp
import time

mlflow_app = MlflowApp.get(mlflow_arn)

while True:
    mlflow_app.refresh()
    print(f"MLflow status: {mlflow_app.status}")
    if mlflow_app.status in ("Created", "Updated"):
        break
    if "Failed" in mlflow_app.status:
        raise RuntimeError(f"MlflowApp failed with status: {mlflow_app.status}")
    time.sleep(20)

# %% [markdown]
# ## 탐색적 데이터 분석 (EDA)
# 이 데이터셋에 대한 탐색적 데이터 분석을 수행합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 데이터셋을 pandas DataFrame으로 로드하고 처음 몇 행을 출력합니다. 은행 마케팅 데이터로, 고객 정보와 마케팅 통화 결과가 담겨 있습니다.

# %%
df_data = pd.read_csv(os.path.join(input_path, file_name), sep=";")

pd.set_option("display.max_columns", 500)  # View all of the columns
df_data  # show first 5 and last 5 rows of the dataframe

# %% [markdown]
# null 값의 수와 데이터 타입을 파악하기 위해 컬럼 메타데이터를 살펴봅니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** `df.info()`로 각 컬럼의 데이터 타입과 null 값 수를 확인합니다. 이 데이터셋은 null이 없는 깨끗한 데이터입니다.

# %%
df_data.info()

# %% [markdown]
# 컬럼 통계를 살펴보면 빠른 정상성 확인이 가능합니다. 예를 들어, 나이의 최솟값은 17, 최댓값은 98, 평균은 40으로 모두 합리적으로 보입니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** `df.describe()`로 수치형 컬럼의 통계(min, max, mean, std)를 확인합니다. 나이 범위(17~98), 통화 지속 시간 등이 합리적인지 검토합니다.

# %%
df_data.describe()

# %% [markdown]
# 다음으로 타겟 컬럼의 분포를 살펴봅니다. 마케팅 통화에 대한 'no' 결과가 'yes'보다 많아 데이터셋이 불균형함을 알 수 있습니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 타겟 컬럼 `y`(정기 예금 가입 여부)의 분포를 막대 그래프로 시각화합니다. 'no'가 'yes'보다 훨씬 많아 **클래스 불균형** 문제가 있음을 확인합니다.

# %%
df_data[target_col].value_counts().plot.bar()
plt.show()

# %% [markdown]
# 누락된 값이 있는지 다시 확인합니다. 이 경우 데이터셋은 매우 깨끗합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 누락값을 확인합니다. 모든 컬럼이 0으로 나오면 결측값이 없는 것입니다.

# %%
df_data.isna().sum()

# %% [markdown]
# 이제 나머지 컬럼들의 분포를 살펴봅니다. 결과를 보면 대부분의 고객이 높은 수준의 교육을 받았고, 대부분 기혼이며, 직업이 불명확한 경우도 있습니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 범주형 컬럼 9개(job, marital, education 등)의 분포를 서브플롯으로 시각화합니다. 직업 분포, 혼인 상태 등 고객 특성을 파악합니다.

# %%
cat_columns = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome']

fig, axs = plt.subplots(3, 3, sharex=False, sharey=False, figsize=(20, 15))

counter = 0
for cat_column in cat_columns:
    value_counts = df_data[cat_column].value_counts()
    
    trace_x = counter // 3
    trace_y = counter % 3
    x_pos = np.arange(0, len(value_counts))
    
    axs[trace_x, trace_y].bar(x_pos, value_counts.values, tick_label = value_counts.index)
    
    axs[trace_x, trace_y].set_title(cat_column)
    
    for tick in axs[trace_x, trace_y].get_xticklabels():
        tick.set_rotation(90)
    
    counter += 1

plt.show()

# %% [markdown]
# 수치형 컬럼에 대해서도 유사한 분포 확인을 수행합니다. 통화 지속 시간이 거의 항상 매우 짧고, 대부분의 고객이 이전 캠페인에서 최근에 연락받지 않았음(`pdays`)을 알 수 있습니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 수치형 컬럼 4개(duration, campaign, pdays, previous)의 히스토그램을 그립니다. 통화 시간이 대부분 짧고, pdays=999(이전 연락 없음)가 많음을 확인합니다.

# %%
num_columns = ['duration', 'campaign', 'pdays', 'previous']

fig, axs = plt.subplots(2, 2, sharex=False, sharey=False, figsize=(20, 15))

counter = 0
for num_column in num_columns:
    
    trace_x = counter // 2
    trace_y = counter % 2
    
    axs[trace_x, trace_y].hist(df_data[num_column])
    
    axs[trace_x, trace_y].set_title(num_column)
    
    counter += 1

plt.show()

# %% [markdown]
# 다음 셀은 특정 컬럼을 타겟 변수와 비교하는 방법을 보여줍니다. 이 경우 혼인 상태를 비교합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 혼인 상태별로 타겟(가입/미가입) 비율을 비교합니다. 특정 그룹이 가입률이 높은지 확인하는 교차 분석입니다.

# %%
j_df = pd.DataFrame()

j_df['yes'] = df_data[df_data[target_col] == 'yes']['marital'].value_counts()
j_df['no'] = df_data[df_data[target_col] == 'no']['marital'].value_counts()

j_df.plot.bar(title = 'Marital status and deposit')

# %% [markdown]
# ## SageMaker와 MLflow 통합으로 실험 추적
# [Amazon SageMaker와 MLflow를 사용하여 머신러닝 실험을 관리](https://docs.aws.amazon.com/sagemaker/latest/dg/mlflow.html)할 수 있습니다.
#
# [MLflow 추적](https://mlflow.org/docs/latest/tracking.html)을 통해 반복 작업의 입력, 파라미터, 설정, 모델을 `실험`과 `실행`으로 자동 추적할 수 있습니다.
#
# SageMaker AI 도메인에는 일반적으로 기본 MLflow 앱이 이미 생성되어 있습니다. 이 기본 앱을 사용하거나 새로 생성할 수 있습니다. 아래 코드는 기본 MLflow 앱을 찾을 수 있는지 확인합니다. 없으면 새 MLflow 앱을 생성합니다. 이 과정은 2~3분 정도 소요될 수 있습니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** MLflow 앱 ARN을 설정하고 앱이 실행 중인지 확인합니다. 앱이 준비되지 않으면 대기합니다.

# %%
if file_source == "local":
    mlflow_app = MlflowApp.get(arn=mlflow_arn)
    max_wait_time = 300  # 5 minutes
    start_time = time.time()
    while mlflow_app.status in ["Creating", "Updating"]:
        if time.time() - start_time > max_wait_time:
            print(f"Timeout: MLflow app '{mlflow_name}' still {mlflow_app.status} after 5 minutes")
            break
        print(f"MLflow app '{mlflow_name}' is {mlflow_app.status}... waiting 30 seconds")
        time.sleep(30)
        mlflow_app.refresh()
    if mlflow_app.status in ["Created", "Updated"]:
        print(f"MLflow app '{mlflow_name}' is ready (status: {mlflow_app.status})")
    else:
        print(f"MLflow app '{mlflow_name}' failed (status: {mlflow_app.status})")

# %% [markdown]
# MLflow 앱이 준비되면 ARN을 설정합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** MLflow 추적 URI를 설정합니다. 이후 모든 `mlflow.*` 호출이 이 앱으로 전송됩니다.

# %%
mlflow.set_tracking_uri(mlflow_arn)

# %% [markdown]
# 실험과 등록된 모델에 고유한 이름을 설정합니다. `experiment_name`은 이 노트북의 모든 실행을 그룹화합니다. `registered_model_name`은 나중에 MLflow 모델 레지스트리에 최적 모델을 등록하는 데 사용됩니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 실험 이름과 등록 모델 이름을 고유하게 생성합니다. 실험은 여러 실행(run)을 묶는 폴더 역할을 합니다.

# %%
experiment_name = name_from_base("from-idea-to-prod-experiment-", short=True)
registered_model_name = name_from_base("from-idea-to-prod-experiment-model-", short=True)

# %% [markdown]
# > 💡 **설명**: **[실습]** 실험 이름을 `%store`로 저장하고 MLflow에 실험을 생성합니다. 이미 존재하면 기존 실험을 사용합니다.

# %%
# %store experiment_name

experiment = mlflow.set_experiment(experiment_name=experiment_name)

# %% [markdown]
# ## 피처 엔지니어링

# %% [markdown]
# 예시로, 처리 스크립트는 다음과 같은 피처 엔지니어링을 구현합니다:
# 1. `pdays`가 `999`이면 `1`, 그렇지 않으면 `0`으로 설정하는 `no_previous_contact` 컬럼 생성
# 1. `job` 컬럼을 기반으로 고객이 재직 중인지 여부를 나타내는 새 컬럼 생성
# 1. 추론 시 높은 정확도로 예측해야 하는 경제 피처를 데이터셋에서 제거
# 1. 통화 전에는 알 수 없는 `duration` 제거
# 1. **원-핫 인코딩**을 사용하여 범주형 변수를 수치형으로 변환
# 1. 타겟 컬럼 `y`를 맨 앞으로 이동
#
# 실제 환경에서는 추가적인 처리, 데이터 품질 처리, 피처 엔지니어링을 구현합니다. 또한 여러 번의 "시도 & 실패" 반복을 거칩니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 피처 엔지니어링을 수행합니다:
# - `pdays==999` → `no_previous_contact=1`
# - 직업 컬럼 → `is_working` 이진화
# - 경제 지표 컬럼 제거 (추론 시 예측 불가)
# - `duration` 제거 (통화 전 알 수 없음)
# - 범주형 변수 원-핫 인코딩
# - 타겟 컬럼을 맨 앞으로 이동

# %%
# Indicator variable to capture when pdays takes a value of 999
df_data["no_previous_contact"] = np.where(df_data["pdays"] == 999, 1, 0)

# Indicator for individuals not actively employed
df_data["not_working"] = np.where(
    np.isin(df_data["job"], ["student", "retired", "unemployed"]), 1, 0
)

# remove unnecessary data
df_model_data = df_data.drop(
    ["duration", "emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed"],
    axis=1,
)


bins = [18, 30, 40, 50, 60, 70, 90]
labels = ['18-29', '30-39', '40-49', '50-59', '60-69', '70-plus']

df_model_data['age_range'] = pd.cut(df_model_data.age, bins, labels=labels, include_lowest=True)
df_model_data = pd.concat([df_model_data, pd.get_dummies(df_model_data['age_range'], prefix='age', dtype=int)], axis=1)
df_model_data.drop('age', axis=1, inplace=True)
df_model_data.drop('age_range', axis=1, inplace=True)

scaled_features = ['pdays', 'previous', 'campaign']
df_model_data[scaled_features] = MinMaxScaler().fit_transform(df_model_data[scaled_features])

df_model_data = pd.get_dummies(df_model_data, dtype=int)  # Convert categorical variables to sets of indicators

# Replace "y_no" and "y_yes" with a single label column, and bring it to the front:
df_model_data = pd.concat(
    [
        df_model_data["y_yes"].rename(target_col),
        df_model_data.drop(["y_no", "y_yes"], axis=1),
    ],
    axis=1,
)

# %% [markdown]
# 전처리 코드를 실행한 후, 빠른 정상성 확인을 위해 데이터셋 자체와 일부 컬럼 통계를 다시 살펴봅니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 피처 엔지니어링 후 데이터프레임을 출력합니다. 원-핫 인코딩으로 컬럼 수가 늘어난 것을 확인합니다.

# %%
df_model_data

# %% [markdown]
# > 💡 **설명**: **[실습]** 변환된 데이터의 통계를 다시 확인합니다. 모든 값이 0~1 범위인지, 이상값이 없는지 검토합니다.

# %%
df_model_data.describe()

# %% [markdown]
# ## 데이터 분할

# %% [markdown]
# 앞으로 사용할 [SageMaker의 XGBoost 알고리즘](https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost.html#InputOutput-XGBoost)은 libSVM 또는 CSV 형식의 데이터를 기대합니다:
#
# - 첫 번째 컬럼에 타겟 변수
# - 헤더 행 없음
#
# 따라서 아래 셀은 먼저 데이터셋을 섞고 훈련, 검증, 테스트 세트로 분할한 후 올바른 형식의 CSV 파일로 저장합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 데이터를 70% 훈련 / 20% 검증 / 10% 테스트로 분할합니다. `random_state=1729`로 재현 가능하게 합니다.

# %%
df_shuffled = df_model_data.sample(frac=1, random_state=1729)
train_idx = int(0.7 * len(df_shuffled))
val_idx = int(0.9 * len(df_shuffled))

train_data = df_shuffled.iloc[:train_idx]
validation_data = df_shuffled.iloc[train_idx:val_idx]
test_data = df_shuffled.iloc[val_idx:]

print(f"Data split > train:{train_data.shape} | validation:{validation_data.shape} | test:{test_data.shape}")

# %% [markdown]
# > 💡 **설명**: **[실습]** 분할된 데이터를 CSV로 저장합니다. SageMaker XGBoost 포맷에 맞게 **헤더 없이**, **타겟 컬럼이 첫 번째**로 저장합니다.

# %%
train_data.to_csv(os.path.join(output_path, "train.csv"), index=False, header=False)
validation_data.to_csv(os.path.join(output_path, "validation.csv"), index=False, header=False)
test_data.to_csv(os.path.join(output_path, "test.csv"), index=False, header=False)

# %% [markdown]
# ### 실험 실행 생성
# MLflow에서 모델 훈련을 로깅하는 것 외에도 데이터 처리도 로깅할 수 있습니다. 이를 통해 전처리와 훈련 정보가 함께 그룹화됩니다.
#
# [`mlflow.start_run()`](https://mlflow.org/docs/latest/python_api/mlflow.html#mlflow.start_run) API를 사용하여 새 실행을 생성하고 [`log_params()`](https://mlflow.org/docs/latest/python_api/mlflow.html#mlflow.log_params) 및 [`log_artifact()`](https://mlflow.org/docs/latest/python_api/mlflow.html#mlflow.log_artifact) MLflow 로깅 함수를 호출하여 실행에 정보를 기록합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** MLflow 실행을 시작하여 피처 엔지니어링 결과를 기록합니다. 분할 비율, 데이터 크기, 분할된 파일을 아티팩트로 로깅합니다.

# %%
with mlflow.start_run(
    run_name=name_from_base("feature-engineering", short=True),
    description="feature-engineering in the notebook 01 ideation"
) as run:
    mlflow.log_params(
        {
            "train": 0.7,
            "validate": 0.2,
            "test": 0.1
        }
    )
    # Log input dataset metadata and output
    mlflow.log_artifact(local_path=os.path.join(input_path, file_name))
    mlflow.log_artifact(local_path=os.path.join(output_path, "train.csv"))
    mlflow.log_artifact(local_path=os.path.join(output_path, "validation.csv"))
    mlflow.log_artifact(local_path=os.path.join(output_path, "test.csv"))

# %% [markdown]
# ## 모델 훈련 및 검증
#
# 이 노트북에서는 노트북 내에서 완전한 로컬 처리와 훈련을 시연하므로 [오픈소스 버전의 XGBoost](https://xgboost.ai/about)를 사용합니다.
#
# 먼저 훈련 데이터셋에서 피처와 레이블을 분리합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 훈련 데이터에서 피처(X)와 레이블(y)을 분리합니다.

# %%
train_features = train_data.drop(target_col, axis=1)
train_label = pd.DataFrame(train_data[target_col])

# %% [markdown]
# XGBoost 알고리즘이 입력으로 받는 데이터 구조를 생성합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** XGBoost가 입력으로 받는 `DMatrix` 객체를 생성합니다.

# %%
dtrain = xgb.DMatrix(train_features, label=train_label)

# %% [markdown]
# 하이퍼파라미터와 기타 변수를 설정합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** XGBoost 하이퍼파라미터를 설정합니다. `max_depth=5`, `eta=0.5`, `objective=binary:logistic` 등입니다.

# %%
hyperparams = {
                "max_depth": 5,
                "eta": 0.5,
                "alpha": 2.5,
                "objective": "binary:logistic",
                "subsample" : 0.8,
                "colsample_bytree" : 0.8,
                "min_child_weight" : 3
              }

num_boost_round = 150
nfold = 3
early_stopping_rounds = 10

# %% [markdown]
# 먼저 훈련 데이터셋의 `nfold` 폴드에 대해 모델을 훈련하고 교차 검증을 실행합니다. 이를 통해 현재 하이퍼파라미터로 모델이 얼마나 잘 일반화되는지 이해할 수 있습니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 5-fold 교차 검증을 실행합니다. 훈련 데이터를 5개로 나눠 번갈아 검증하여 모델의 일반화 성능을 평가합니다. AUC가 0.7 이상이면 양호합니다.

# %%
cv_results = xgb.cv(
    params=hyperparams,
    dtrain=dtrain,
    num_boost_round=num_boost_round,
    nfold=nfold,
    early_stopping_rounds=early_stopping_rounds,
    metrics=["auc"],
    seed=10,
)

# %% [markdown]
# 모델 성능을 이해하기 위해 모든 메트릭을 가져와 출력합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 교차 검증 결과에서 AUC 메트릭을 추출하여 딕셔너리로 정리합니다.

# %%
metrics_data = {
    "binary_classification_metrics": {
        "validation:auc": {
            "value": cv_results.iloc[-1]["test-auc-mean"],
            "standard_deviation": cv_results.iloc[-1]["test-auc-std"]
        },
        "train:auc": {
            "value": cv_results.iloc[-1]["train-auc-mean"],
            "standard_deviation": cv_results.iloc[-1]["train-auc-std"]
        },
    }
}

# %% [markdown]
# > 💡 **설명**: **[실습]** 교차 검증 AUC를 출력합니다. train-auc와 validation-auc의 차이가 크면 과적합을 의심합니다.

# %%
print(f"Cross-validated train-auc:{cv_results.iloc[-1]['train-auc-mean']:.2f}")
print(f"Cross-validated validation-auc:{cv_results.iloc[-1]['test-auc-mean']:.2f}")

# %% [markdown]
# > 💡 **설명**: **[실습]** 교차 검증의 전체 결과 테이블을 출력합니다. 라운드별 AUC 변화를 확인합니다.

# %%
cv_results

# %% [markdown]
# 다음으로, 훈련 데이터셋을 여러 폴드로 분할하는 대신 전체 훈련 데이터셋으로 모델을 재훈련합니다.

# %% [markdown]
# ### 모델 훈련
# [MLflow 모델 플레이버](https://mlflow.org/docs/latest/python_api/index.html#python-api)와 [로깅 함수](https://mlflow.org/docs/latest/tracking/tracking-api.html#tracking-logging-functions)를 사용하여 실험 실행에 파라미터, 모델, 모델 메트릭, 다양한 메타데이터를 로깅합니다.
#
# 조기 종료를 위해 테스트 데이터셋을 사용합니다. 먼저 피처와 타겟 레이블을 분리하고 알고리즘이 기대하는 데이터 구조를 생성합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 테스트 데이터에서 피처와 레이블을 분리하고 DMatrix를 생성합니다. 조기 종료(early stopping)에 사용됩니다.

# %%
test_features = test_data.drop(target_col, axis=1)
test_label = pd.DataFrame(test_data[target_col])
dtest = xgb.DMatrix(test_features, label=test_label)

# %% [markdown]
# 아래 셀은 다양한 `max_depth` 값으로 모델을 훈련하고 각 실행을 MLflow에 로깅하는 간단한 훈련 루프를 보여줍니다. 이를 통해 나중에 결과를 쉽게 비교할 수 있습니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** `max_depth` 값을 3, 5, 7로 바꿔가며 3번 훈련하고 각 실행을 MLflow에 기록합니다. 가장 높은 AUC를 기록한 실행의 `run_id`를 저장합니다.

# %%
max_metric = 0.0
best_model_run_id = 0

with mlflow.start_run(
    run_name=name_from_base("training-", short=True),
    description=f"Fit estimator with different max_depth"
) as parent_run:
    mlflow.set_tags({'mlflow.user':user_profile_name})
    
    # Train the model for different max_depth values
    for index, depth in enumerate([2, 5, 10, 15, 20]):
        hyperparams["max_depth"] = depth
        print(f"Fit estimator with max_depth={depth}")
    
        with mlflow.start_run(
            run_name=f"max_depth={depth}",
            description=f"Fit estimator with max_depth={depth}",
            nested=True
        ) as child_run:
            mlflow.set_tags({'mlflow.user':user_profile_name})
            
            mlflow.xgboost.autolog(silent=True)
            
            # Train the model
            model = xgb.train(
                params=hyperparams, 
                dtrain=dtrain, 
                evals = [(dtrain,'train'), (dtest,'eval')], 
                num_boost_round=num_boost_round, 
                early_stopping_rounds=early_stopping_rounds, 
                verbose_eval = 0
            )
    
            # Calculate metrics
            test_auc = roc_auc_score(test_label, model.predict(dtest))
            train_auc = roc_auc_score(train_label, model.predict(dtrain))
            
            # Log hyperparameters and metrics to the run
            mlflow.log_params(hyperparams)
            mlflow.log_metrics({"test_auc":test_auc, "train_auc":train_auc}, step=index)
    
            if test_auc > max_metric:
                best_model_run_id = child_run.info.run_id
                max_metric = test_auc
    
            print(f"Test AUC: {test_auc:.4f} | Train AUC: {train_auc:.4f}")

# %% [markdown]
# ### MLflow 모델 레지스트리에 최적 모델 등록
# MLflow에서 실험과 실행을 추적하는 것 외에도 [모델 레지스트리](https://mlflow.org/docs/latest/model-registry.html#adding-an-mlflow-model-to-the-model-registry)로 사용할 수 있습니다.
#
# 이 예제에서는 [mlflow.register_model()](https://mlflow.org/docs/latest/python_api/mlflow.html#mlflow.register_model) API를 사용하여 최적 모델을 등록된 모델 이름 아래 새 버전으로 등록합니다.
#
# <div class="alert alert-info">
# <b>💡 자동 동기화:</b> MLflow 앱이 <code>AutoModelRegistrationEnabled</code>로 생성되었으므로, 이 호출은 <a href="https://docs.aws.amazon.com/sagemaker/latest/dg/model-registry.html">SageMaker 모델 레지스트리</a>에 해당 모델 패키지도 자동으로 생성합니다.
# </div>

# %% [markdown]
# > 💡 **설명**: **[실습]** 최적 모델을 MLflow 모델 레지스트리에 등록합니다. MLflow 앱이 `AutoModelRegistrationEnabled`로 생성되어 있으므로 **SageMaker 모델 레지스트리에도 자동으로 동기화**됩니다.

# %%
model_uri = f"runs:/{best_model_run_id}/model"
mv = mlflow.register_model(model_uri, registered_model_name)

# %% [markdown]
# ## MLflow UI로 실험 탐색
# Studio UI의 **MLflow** 위젯 > **Open MLflow** 버튼에서 MLflow 앱에 접근할 수 있습니다.
#
# ![](img/mlflow-apps-studio.png)
#
# MLflow UI가 새 브라우저 창에서 열립니다. 여기서 실험을 선택하여 그 안의 실행을 볼 수 있습니다.
#
# ![](img/experiment-mlflow.png)
#
# **차트 보기**로 전환하여 다양한 실행을 비교할 수 있습니다.
#
# ![](img/comparing-runs.png)
#
# **모델**로 변경하여 등록된 모델과 모든 버전을 확인합니다.
#
# ![](img/models-mlflow.png)

# %% [markdown]
# ## 선택 사항: 노트북을 SageMaker 작업으로 실행
# 때로는 노트북을 비대화형 예약 작업으로 실행하고 싶은 시나리오가 있습니다. Studio는 기존 Amazon EventBridge, SageMaker Training, SageMaker Pipelines 서비스를 기반으로 구축된 빠르고 간단한 도구를 제공하여 노트북 작업을 대화형으로 예약할 수 있습니다.
#
# 노트북을 온디맨드 또는 원하는 일정에 따라 SageMaker 작업으로 실행할 수 있습니다. 또한 여러 노트북을 병렬로 실행하고 노트북의 셀을 파라미터화할 수 있습니다.
#
# ### 헤드리스 실행을 위한 노트북 적응
# 헤드리스 노트북은 Studio 환경 외부의 셸에서 실행됩니다. 따라서 노트북의 코드는 Studio 로컬 스토리지, 환경 변수, Python 저장소에 의존하거나 접근할 수 없습니다.
#
# ### 실행 방법
# 개발자 가이드의 [노트북 기반 워크플로우](https://docs.aws.amazon.com/sagemaker/latest/dg/notebook-auto-run.html) 지침에 따라 이 노트북을 SageMaker 작업으로 비대화형 모드로 실행하세요:
# 1. Studio 실행 역할에 대한 신뢰 정책 및 추가 IAM 권한을 [구성](https://docs.aws.amazon.com/sagemaker/latest/dg/scheduled-notebook-policies-studio.html)합니다
# 2. 아래에 지정된 파라미터를 제공합니다
# 3. 온디맨드로 노트북을 실행하거나 작업을 예약합니다
# 4. 결과를 탐색합니다

# %% [markdown]
# ### 파라미터 설정
# 다음 셀은 노트북 작업을 생성할 때 설정해야 하는 파라미터를 출력합니다.

# %% [markdown]
# > 💡 **설명**: **[실습]** 노트북을 SageMaker 헤드리스 작업으로 실행할 때 필요한 파라미터 값을 출력합니다. 지금은 참고용입니다.

# %%
print(f"""mlflow_arn = {mlflow_arn}
file_source = S3
input_path = /opt/ml/input/data/sagemaker_headless_execution 
output_path = /opt/ml/output/data
bucket_name = {bucket_name}
bucket_prefix = from-idea-to-prod/xgboost
user_profile_name = sagemaker_notebook_job""")

# %% [markdown]
# 노트북을 파라미터화하려면 노트북의 단일 셀에 `parameters` 태그를 [설정](https://docs.aws.amazon.com/sagemaker/latest/dg/notebook-auto-run-troubleshoot-override.html)하여 "파라미터 셀"로 표시합니다. SageMaker 노트북 실행은 런타임에 해당 `parameters` 태그가 붙은 셀 바로 다음에 새로 생성된 셀을 삽입합니다.
#
# 노트북 실행 작업은 JupyterLab EBS 볼륨에 접근할 수 없습니다. 노트북에 전달해야 하는 데이터는 S3 버킷에 복사해야 합니다.
#
# 이 노트북을 SageMaker 작업으로 실행하려면 노트북 작업 표시줄에서 **노트북 작업 생성** 아이콘을 선택하세요:
#
# ![](img/notebook-as-sm-job-run.png)
#
# 양식의 **파라미터** 섹션에서 앞서 출력된 파라미터를 지정된 값으로 설정합니다. **입력 폴더로 작업 실행**을 체크했는지 확인하세요.
#
# ![](img/notebook-as-sm-job-parameters.png)
#
# 또한 **추가 옵션**을 펼치고 **시작 스크립트** 필드에서 드롭다운 메뉴에 표시되는 라이프사이클 스크립트를 선택합니다.
# 나머지는 그대로 두세요.
#
# ![](img/additional-startup-script.png)
#
# **지금 실행** 또는 **일정에 따라 실행**을 선택하고 **생성**을 클릭합니다.

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
#
# In this notebook you:
# - Explored and visualized the bank marketing dataset
# - Engineered features (one-hot encoding, scaling, new indicator columns)
# - Trained an XGBoost model locally with cross-validation and hyperparameter comparison
# - Tracked all experiments and metrics in MLflow
# - Registered the best model in the MLflow Model Registry (which auto-synced to SageMaker Model Registry)
# - Deployed and tested the model using `ModelBuilder`
#
# Everything ran locally in this notebook. In the next step, you'll move the same data processing and training logic into **SageMaker managed containers** — gaining scalability, reproducibility, and separation of concerns.

# %% [markdown]
# ## Continue with the step 2
# Open the step 2 [notebook](02-sagemaker-containers.ipynb).

# %% [markdown]
# ## Additional resources
# - [SageMaker JupyterLab guide](https://docs.aws.amazon.com/sagemaker/latest/dg/studio-updated-jl.html)
# -  [Operationalize your Amazon SageMaker Studio notebooks as scheduled notebook jobs](https://aws.amazon.com/blogs/machine-learning/operationalize-your-amazon-sagemaker-studio-notebooks-as-scheduled-notebook-jobs/)
# - [MLflow Apps in SageMaker](https://docs.aws.amazon.com/sagemaker/latest/dg/mlflow-app-setup.html)
# - [scikit-learn dataset transformations](https://scikit-learn.org/stable/data_transforms.html)
# - [Extracting, transforming and selecting features](https://spark.apache.org/docs/latest/ml-features.html)
#
# ### Hands-on examples
# - [Official Amazon SageMaker Examples repository](https://github.com/aws/amazon-sagemaker-examples)
# - [Community Amazon SageMaker Examples repository](https://github.com/aws/amazon-sagemaker-examples-community)

# %% [markdown]
# # Shutdown kernel

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
